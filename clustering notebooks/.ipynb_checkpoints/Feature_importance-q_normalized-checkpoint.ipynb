# %%
##import required packages

import pandas as pd
from xgboost import plot_importance
from xgboost import XGBClassifier
import seaborn as sns
from sklearn.feature_selection import RFE
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ### Reading clusterwise labelled data
#
# Note: The classes were predicted by dropping the features with high correlation values and then the predicted labels were added to the original data with all coulumns

# %%
c2=pd.read_csv("../data/Clustering labelled data_q_normalized/2_cluster.csv").drop(['Unnamed: 0'],axis=1).dropna()
c3=pd.read_csv("../data/Clustering labelled data_q_normalized/3_cluster.csv").drop(['Unnamed: 0'],axis=1).dropna()
c4=pd.read_csv("../data/Clustering labelled data_q_normalized/4_cluster.csv").drop(['Unnamed: 0'],axis=1).dropna()
c5=pd.read_csv("../data/Clustering labelled data_q_normalized/5_cluster.csv").drop(['Unnamed: 0'],axis=1).dropna()
c6=pd.read_csv("../data/Clustering labelled data_q_normalized/6_cluster.csv").drop(['Unnamed: 0'],axis=1).dropna()

# %% [markdown]
# # Clusters =2

# %%
c2
# Out:
#        FIPS    State      County  q_Years of Potential Life Lost Rate  \
# 0      1001  Alabama     Autauga                             0.519452
# 1      1003  Alabama     Baldwin                             0.410077
# 2      1005  Alabama     Barbour                             0.791454
# 3      1007  Alabama        Bibb                             0.920281
# 4      1009  Alabama      Blount                             0.884566
# ...     ...      ...         ...                                  ...
# 3128  56033  Wyoming    Sheridan                             0.424107
# 3129  56035  Wyoming    Sublette                             0.233737
# 3130  56037  Wyoming  Sweetwater                             0.482462
# 3131  56039  Wyoming       Teton                             0.091837
# 3132  56041  Wyoming       Uinta                             0.406888
#
#       q_% Fair or Poor Health  q_Average Number of Physically Unhealthy Days  \
# 0                    0.745536                                       0.851403
# 1                    0.525191                                       0.659439
# 2                    0.981505                                       0.969707
# 3                    0.654974                                       0.801658
# 4                    0.798151                                       0.882653
# ...                       ...                                            ...
# 3128                 0.106186                                       0.184311
# 3129                 0.082270                                       0.070153
# 3130                 0.296237                                       0.218112
# 3131                 0.060587                                       0.075574
# 3132                 0.355548                                       0.325893
#
#       q_Average Number of Mentally Unhealthy Days  q_% Low Birthweight  \
# 0                                        0.788584             0.683992
# 1                                        0.588967             0.634566
# 2                                        0.956314             0.931441
# 3                                        0.734375             0.874043
# 4                                        0.889031             0.465561
# ...                                           ...                  ...
# 3128                                     0.224490             0.236926
# 3129                                     0.030931             0.526148
# 3130                                     0.196747             0.825893
# 3131                                     0.053571             0.497449
# 3132                                     0.217156             0.860013
#
#       q_% Smokers  q_Food Environment Index  ...  q_% Nonwhite  \
# 0        0.606505                  0.327009  ...      0.747768
# 1        0.554209                  0.658482  ...      0.598852
# 2        0.894133                  0.066805  ...      0.947704
# 3        0.699617                  0.565370  ...      0.749681
# 4        0.707270                  0.824936  ...      0.219707
# ...           ...                       ...  ...           ...
# 3128     0.289860                  0.437978  ...      0.249362
# 3129     0.129783                  0.859056  ...      0.161033
# 3130     0.605548                  0.522640  ...      0.365434
# 3131     0.202168                  0.748884  ...      0.481505
# 3132     0.529337                  0.400032  ...      0.346939
#
#       q_% households wo car  q_Number of Hospitals  q_% disabled  \
# 0                  0.499043               0.414700      0.794324
# 1                  0.154974               0.877551      0.357781
# 2                  0.873724               0.414700      0.907685
# 3                  0.539222               0.414700      0.612085
# 4                  0.240115               0.414700      0.382812
# ...                     ...                    ...           ...
# 3128               0.276467               0.720344      0.268973
# 3129               0.017857               0.093909      0.253189
# 3130               0.052934               0.720344      0.208227
# 3131               0.055804               0.414700      0.006696
# 3132               0.208865               0.720344      0.652583
#
#       q_% Without Health Insurance  q_% Limited English Proficiency  \
# 0                         0.457589                         0.427615
# 1                         0.677774                         0.643176
# 2                         0.694675                         0.652423
# 3                         0.499203                         0.439732
# 4                         0.729432                         0.650510
# ...                            ...                              ...
# 3128                      0.532526                         0.431441
# 3129                      0.587372                         0.305804
# 3130                      0.555804                         0.789222
# 3131                      0.688935                         0.911990
# 3132                      0.580357                         0.331952
#
#       q_% workers commuting by public transit  \
# 0                                    0.271292
# 1                                    0.271292
# 2                                    0.485327
# 3                                    0.641467
# 4                                    0.271292
# ...                                       ...
# 3128                                 0.271292
# 3129                                 0.485327
# 3130                                 0.936045
# 3131                                 0.965391
# 3132                                 0.958054
#
#       q_% Veterans in Civilian Adult Population  q_opioid death rate  class
# 0                                      0.908801             0.129783    2.0
# 1                                      0.897003             0.072385    0.0
# 2                                      0.298788             0.421237    2.0
# 3                                      0.225287             0.464286    2.0
# 4                                      0.464764             0.122449    2.0
# ...                                         ...                  ...    ...
# 3128                                   0.870536             0.337691    3.0
# 3129                                   0.651945             0.770089    3.0
# 3130                                   0.404496             0.207270    3.0
# 3131                                   0.061224             0.451531    3.0
# 3132                                   0.341518             0.506537    3.0
#
# [3133 rows x 96 columns]

# %%
print("The number of entries per class are:\n{}".format(c2['class'].value_counts()),c2['class'].hist())
# Out:
# The number of entries per class are:
# 1.0    962
# 2.0    809
# 0.0    767
# 3.0    595
# Name: class, dtype: int64 AxesSubplot(0.125,0.125;0.775x0.755)

# %%
X1=c2.drop(columns=["FIPS","State","County","class"],axis=1)
y1=c2['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X1, y1)
X_red=None
X_red=c2[X1.columns[(selector.get_support())]]
print("Top features are\n")
for val in X_red.columns.to_list():
    print(val)
# Out:
# Top features are
#
# q_% Fair or Poor Health
# q_% With Access to Exercise Opportunities
# q_Chlamydia Rate
# q_Average Daily PM2.5
# q_Life Expectancy
# q_Child Mortality Rate
# q_Population
# q_% Non-Hispanic White
# q_countycode
# q_internet_hhs

# %%
## Boxplots

for i in X_red.columns:
    plt.figure()
    sns.boxplot(x=y1,y=X_red[i],data=X_red)

# %%
## Violin Plots

for i in X_red.columns:
    plt.figure(frameon=True,)
    sns.violinplot(x=y1,y=X_red[i],data=X_red)

# %% [markdown]
# ## 1st Cluster

# %%
data1=c2[c2['class']==0]
data1_bar=c2[c2['class']!=0]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c21=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c21['class'].value_counts())

X=c21.drop(['class'],axis=1)
y=c21['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c2[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    767
# 0    767
# Name: class, dtype: int64
# Top features are
#
# q_Life Expectancy
# q_countycode
# q_% Rural
# q_% Severe Housing Problems
# q_internet_consumer
# q_% With Access to Exercise Opportunities
# q_Population
# q_% Severe Housing Cost Burden
# q_Juvenile Arrest Rate
# q_% Asian

# %% [markdown]
# ## 2nd cluster

# %%
data1=c2[c2['class']==1]
data1_bar=c2[c2['class']!=1]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c22=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c22['class'].value_counts())

X=c22.drop(['class'],axis=1)
y=c22['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c2[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    962
# 0    962
# Name: class, dtype: int64
# Top features are
#
# q_Average Reading Performance
# q_% Non-Hispanic White
# q_% Hispanic
# q_% Homeowners
# q_internet_hhs
# q_Child Mortality Rate
# q_Average Daily PM2.5
# q_Violent Crime Rate
# q_Chlamydia Rate
# q_countycode

# %% [markdown]
# # Clusters = 3

# %%
print("The number of entries per class are:\n{}".format(c3['class'].value_counts()),c3['class'].hist())
# Out:
# The number of entries per class are:
# 0    1170
# 2    1025
# 1     939
# Name: class, dtype: int64 AxesSubplot(0.125,0.125;0.775x0.755)

# %%
X1=c3.drop(columns=["FIPS","State","County","class"],axis=1)
y1=c3['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X1, y1)
X_red=None
X_red=c3[X1.columns[(selector.get_support())]]
print("Top features are\n")
for val in X_red.columns.to_list():
    print(val)
# Out:
# Top features are
#
# q_Years of Potential Life Lost Rate
# q_% Fair or Poor Health
# q_% With Access to Exercise Opportunities
# q_Chlamydia Rate
# q_Average Daily PM2.5
# q_Child Mortality Rate
# q_Black/White Segregation Index
# q_countycode
# q_internet_hhs
# q_% workers commuting by public transit

# %%
## Boxplots

for i in X_red.columns:
    plt.figure(frameon=True,)
    sns.boxplot(x=y1,y=X_red[i],data=X_red)

# %%
## Violin Plots

for i in X_red.columns:
    plt.figure(frameon=True,)
    sns.violinplot(x=y1,y=X_red[i],data=X_red)

# %% [markdown]
# ## 1st cluster

# %%
data1=c3[c3['class']==0]
data1_bar=c3[c3['class']!=0]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c31=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c31['class'].value_counts())

X=c31.drop(['class'],axis=1)
y=c31['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c3[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    1170
# 0    1170
# Name: class, dtype: int64
# Top features are
#
# q_Years of Potential Life Lost Rate
# q_Juvenile Arrest Rate
# q_countycode
# q_internet_hhs
# q_% Children Uninsured
# q_Average Daily PM2.5
# q_% With Access to Exercise Opportunities
# q_Life Expectancy
# q_% Fair or Poor Health
# q_% workers commuting by public transit

# %% [markdown]
# ## 2nd cluster

# %%
data1=c3[c3['class']==1]
data1_bar=c3[c3['class']!=1]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c32=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c32['class'].value_counts())

X=c32.drop(['class'],axis=1)
y=c32['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c3[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    939
# 0    939
# Name: class, dtype: int64
# Top features are
#
# q_Years of Potential Life Lost Rate
# q_Child Mortality Rate
# q_HIV Prevalence Rate
# q_% Insufficient Sleep
# q_Population
# q_countycode
# q_Chlamydia Rate
# q_Average Number of Mentally Unhealthy Days
# q_internet_hhs
# q_% Nonwhite

# %% [markdown]
# ## 3rd cluster

# %%
data1=c3[c3['class']==2]
data1_bar=c3[c3['class']!=2]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c33=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c33['class'].value_counts())

X=c33.drop(['class'],axis=1)
y=c33['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c3[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    1025
# 0    1025
# Name: class, dtype: int64
# Top features are
#
# q_countycode
# q_% workers commuting by public transit
# q_internet_hhs
# q_Juvenile Arrest Rate
# q_% Native Hawaiian/Other Pacific Islander
# q_% With Access to Exercise Opportunities
# q_internet_all
# q_% Rural
# q_% Severe Housing Cost Burden
# q_% Severe Housing Problems

# %% [markdown]
# # Clusters = 4

# %%
print("The number of entries per class are:\n{}".format(c4['class'].value_counts()),c4['class'].hist())
# Out:
# The number of entries per class are:
# 1    952
# 2    870
# 0    745
# 3    567
# Name: class, dtype: int64 AxesSubplot(0.125,0.125;0.775x0.755)

# %%
X1=c4.drop(columns=["FIPS","State","County","class"],axis=1)
y1=c4['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X1, y1)
X_red=None
X_red=c4[X1.columns[(selector.get_support())]]
print("Top features are\n")
for val in X_red.columns.to_list():
    print(val)
# Out:
# Top features are
#
# q_% Fair or Poor Health
# q_Chlamydia Rate
# q_% With Annual Mammogram
# q_Average Daily PM2.5
# q_% Severe Housing Problems
# q_Population
# q_% Rural
# q_countycode
# q_internet_hhs
# q_% Without Health Insurance

# %%
## Boxplots

for i in X_red.columns:
    plt.figure(frameon=True,)
    sns.boxplot(x=y1,y=X_red[i],data=X_red)

# %%
## Violin Plots

for i in X_red.columns:
    plt.figure(frameon=True,)
    sns.violinplot(x=y1,y=X_red[i],data=X_red)

# %% [markdown]
# ## 1st cluster

# %%
data1=c4[c4['class']==0]
data1_bar=c4[c4['class']!=0]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c41=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c41['class'].value_counts())



X=c41.drop(['class'],axis=1)
y=c41['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c4[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
#     sns.violinplot(x=y,y=X[i],data=X)
# Out:
# 1    745
# 0    745
# Name: class, dtype: int64
# Top features are
#
# q_countycode
# q_High School Graduation Rate
# q_% workers commuting by public transit
# q_% Rural
# q_% Native Hawaiian/Other Pacific Islander
# q_Juvenile Arrest Rate
# q_% Severe Housing Problems
# q_Chlamydia Rate
# q_% With Access to Exercise Opportunities
# q_Population

# %% [markdown]
# ## 2nd cluster

# %%
data1=c4[c4['class']==1]
data1_bar=c4[c4['class']!=1]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c42=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c42['class'].value_counts())


X=c42.drop(['class'],axis=1)
y=c42['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c4[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    952
# 0    952
# Name: class, dtype: int64
# Top features are
#
# q_Years of Potential Life Lost Rate
# q_countycode
# q_Juvenile Arrest Rate
# q_covid_deaths
# q_Life Expectancy
# q_Average Daily PM2.5
# q_% With Annual Mammogram
# q_Dentist Rate
# q_% Rural
# q_% Fair or Poor Health

# %% [markdown]
# ## 3rd cluster

# %%
data1=c4[c4['class']==2]
data1_bar=c4[c4['class']!=2]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c43=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c43['class'].value_counts())

X=c43.drop(['class'],axis=1)
y=c43['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c4[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    870
# 0    870
# Name: class, dtype: int64
# Top features are
#
# q_Average Reading Performance
# q_% Severe Housing Problems
# q_Population
# q_% Children Uninsured
# q_% Hispanic
# q_% Vaccinated
# q_% Frequent Mental Distress
# q_countycode
# q_% With Annual Mammogram
# q_% Without Health Insurance

# %% [markdown]
# ## 4th cluster

# %%
data1=c4[c4['class']==3]
data1_bar=c4[c4['class']!=3]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c44=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c44['class'].value_counts())

X=c44.drop(['class'],axis=1)
y=c44['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c4[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    567
# 0    567
# Name: class, dtype: int64
# Top features are
#
# q_Years of Potential Life Lost Rate
# q_% Long Commute - Drives Alone
# q_% Children Uninsured
# q_Chlamydia Rate
# q_% Black
# q_% American Indian & Alaska Native
# q_Population
# q_Average Daily PM2.5
# q_internet_hhs
# q_countycode

# %% [markdown]
# # Clusters = 5

# %%
print("The number of entries per class are:\n{}".format(c5['class'].value_counts()),c5['class'].hist())
# Out:
# The number of entries per class are:
# 1    871
# 0    779
# 4    554
# 3    488
# 2    442
# Name: class, dtype: int64 AxesSubplot(0.125,0.125;0.775x0.755)

# %%
X1=c5.drop(columns=["FIPS","State","County","class"],axis=1)
y1=c5['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X1, y1)
X_red=None
X_red=c5[X1.columns[(selector.get_support())]]
print("Top features are\n")
for val in X_red.columns.to_list():
    print(val)
# Out:
# Top features are
#
# q_% Fair or Poor Health
# q_% With Annual Mammogram
# q_Average Daily PM2.5
# q_Suicide Rate (Age-Adjusted)
# q_Population
# q_% American Indian & Alaska Native
# q_% Rural
# q_countycode
# q_internet_hhs
# q_% Without Health Insurance

# %%
## Boxplots

for i in X_red.columns:
    plt.figure(frameon=True,)
    sns.boxplot(x=y1,y=X_red[i],data=X_red)

# %%
## Violin Plots

for i in X_red.columns:
    plt.figure(frameon=True,)
    sns.violinplot(x=y1,y=X_red[i],data=X_red)

# %% [markdown]
# ## 1st cluster

# %%
data1=c5[c5['class']==0]
data1_bar=c5[c5['class']!=0]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c51=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c51['class'].value_counts())

X=c51.drop(['class'],axis=1)
y=c51['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c5[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    779
# 0    779
# Name: class, dtype: int64
# Top features are
#
# q_Average Reading Performance
# q_% Without Health Insurance
# q_internet_hhs
# q_% Frequent Mental Distress
# q_countycode
# q_% Non-Hispanic White
# q_% Vaccinated
# q_% With Annual Mammogram
# q_Population
# q_% Severe Housing Problems

# %% [markdown]
# ## 2nd cluster

# %%
data1=c5[c5['class']==1]
data1_bar=c5[c5['class']!=1]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c52=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c52['class'].value_counts())

X=c52.drop(['class'],axis=1)
y=c52['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c5[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    871
# 0    871
# Name: class, dtype: int64
# Top features are
#
# q_% Non-Hispanic White
# q_Life Expectancy
# q_% Insufficient Sleep
# q_Juvenile Arrest Rate
# q_% Rural
# q_countycode
# q_Average Daily PM2.5
# q_Heart Disease Death Rate
# q_% Without Health Insurance
# q_% Fair or Poor Health

# %% [markdown]
# ## 3rd cluster

# %%
data1=c5[c5['class']==2]
data1_bar=c5[c5['class']!=2]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c53=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c53['class'].value_counts())

X=c53.drop(['class'],axis=1)
y=c53['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c5[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    442
# 0    442
# Name: class, dtype: int64
# Top features are
#
# q_% Black
# q_Suicide Rate (Age-Adjusted)
# q_countycode
# q_internet_nonconsumer
# q_% American Indian & Alaska Native
# q_% Severe Housing Problems
# q_Average Daily PM2.5
# q_High School Graduation Rate
# q_% Vaccinated
# q_% With Annual Mammogram

# %% [markdown]
# ## 4th cluster

# %%
data1=c5[c5['class']==3]
data1_bar=c5[c5['class']!=3]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c54=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c54['class'].value_counts())

X=c54.drop(['class'],axis=1)
y=c54['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c5[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    488
# 0    488
# Name: class, dtype: int64
# Top features are
#
# q_Years of Potential Life Lost Rate
# q_% Children Uninsured
# q_Suicide Rate (Age-Adjusted)
# q_Average Number of Mentally Unhealthy Days
# q_Average Daily PM2.5
# q_Population
# q_% American Indian & Alaska Native
# q_%  Adults with Obesity
# q_countycode
# q_internet_hhs

# %% [markdown]
# ## 5th cluster

# %%
data1=c5[c5['class']==4]
data1_bar=c5[c5['class']!=4]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c54=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)



X=c54.drop(['class'],axis=1)
y=c54['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c5[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)

for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# print(c54['class'].value_counts())
# print("No modelling required as only 3 features")
# Out:
# Top features are
#
# q_% Vaccinated
# q_% Severe Housing Problems
# q_Presence of Water Violation
# q_% Black
# q_% Asian
# q_% Rural
# q_countycode
# q_internet_nonconsumer
# q_% Children Uninsured
# q_% workers commuting by public transit

# %% [markdown]
# # Clusters = 6

# %%
print("The number of entries per class are:\n{}".format(c6['class'].value_counts()),c6['class'].hist())
# Out:
# The number of entries per class are:
# 3.0    722
# 4.0    545
# 0.0    531
# 1.0    478
# 2.0    449
# 5.0    409
# Name: class, dtype: int64 AxesSubplot(0.125,0.125;0.775x0.755)

# %%
X1=c6.drop(columns=["FIPS","State","County","class"],axis=1)
y1=c6['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X1, y1)
X_red=None
X_red=c6[X1.columns[(selector.get_support())]]
print("Top features are\n")
for val in X_red.columns.to_list():
    print(val)
# Out:
# Top features are
#
# q_% Fair or Poor Health
# q_% With Annual Mammogram
# q_Average Daily PM2.5
# q_Population
# q_% Black
# q_% American Indian & Alaska Native
# q_% Rural
# q_countycode
# q_internet_all
# q_internet_hhs

# %%
## Boxplots

for i in X_red.columns:
    plt.figure(frameon=True,)
    sns.boxplot(x=y1,y=X_red[i],data=X_red)

# %%
## Violin Plots

for i in X_red.columns:
    plt.figure(frameon=True,)
    sns.violinplot(x=y1,y=X_red[i],data=X_red)

# %% [markdown]
# ## 1st cluster

# %%
data1=c6[c6['class']==0]
data1_bar=c6[c6['class']!=0]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c61=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c61['class'].value_counts())

X=c61.drop(['class'],axis=1)
y=c61['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c6[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    531
# 0    531
# Name: class, dtype: int64
# Top features are
#
# q_% Excessive Drinking
# q_Chlamydia Rate
# q_countycode
# q_% Hispanic
# q_Life Expectancy
# q_% Without Health Insurance
# q_covid_cases
# q_Child Mortality Rate
# q_% Fair or Poor Health
# q_% Black

# %% [markdown]
# ## 2nd cluster

# %%
data1=c6[c6['class']==1]
data1_bar=c6[c6['class']!=1]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c62=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c62['class'].value_counts())

X=c62.drop(['class'],axis=1)
y=c62['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c6[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    478
# 0    478
# Name: class, dtype: int64
# Top features are
#
# q_% Rural
# q_countycode
# q_% Vaccinated
# q_internet_hhs
# q_% Without Health Insurance
# q_% With Access to Exercise Opportunities
# q_% Severe Housing Problems
# q_internet_consumer
# q_% Severe Housing Cost Burden
# q_% workers commuting by public transit

# %% [markdown]
# ## 3rd cluster

# %%
data1=c6[c6['class']==2]
data1_bar=c6[c6['class']!=2]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c63=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c63['class'].value_counts())

X=c63.drop(['class'],axis=1)
y=c63['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c6[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    449
# 0    449
# Name: class, dtype: int64
# Top features are
#
# q_Years of Potential Life Lost Rate
# q_HIV Prevalence Rate
# q_% Insufficient Sleep
# q_% Children Uninsured
# q_Suicide Rate (Age-Adjusted)
# q_% With Access to Exercise Opportunities
# q_% American Indian & Alaska Native
# q_Average Number of Mentally Unhealthy Days
# q_countycode
# q_Population

# %% [markdown]
# ## 4th cluster

# %%
data1=c6[c6['class']==3]
data1_bar=c6[c6['class']!=3]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c64=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)

print(c64['class'].value_counts())

X=c64.drop(['class'],axis=1)
y=c64['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c6[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    722
# 0    722
# Name: class, dtype: int64
# Top features are
#
# q_Average Reading Performance
# q_% Fair or Poor Health
# q_% American Indian & Alaska Native
# q_% Non-Hispanic White
# q_countycode
# q_internet_all
# q_% Children Uninsured
# q_% Without Health Insurance
# q_% Severe Housing Problems
# q_% With Annual Mammogram

# %% [markdown]
# ## 5th cluster

# %%
data1=c6[c6['class']==4]
data1_bar=c6[c6['class']!=4]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c65=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c65['class'].value_counts())

X=c65.drop(['class'],axis=1)
y=c65['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c6[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    545
# 0    545
# Name: class, dtype: int64
# Top features are
#
# q_% Rural
# q_Average Daily PM2.5
# q_Juvenile Arrest Rate
# q_countycode
# q_% With Annual Mammogram
# q_Child Mortality Rate
# q_Heart Disease Death Rate
# q_Chlamydia Rate
# q_% Nonwhite
# q_% Fair or Poor Health

# %% [markdown]
# ## 6th cluster

# %%
data1=c6[c6['class']==5]
data1_bar=c6[c6['class']!=5]
if len(data1)>1500:
    d=data1_bar
else:
    d=data1_bar.sample(n=len(data1))
data1['class']=1
d['class']=0
c66=pd.concat([data1,d],ignore_index=True).drop(columns=["FIPS","State","County"],axis=1)
print(c66['class'].value_counts())

X=c66.drop(['class'],axis=1)
y=c66['class']
top_n_features=10
model = XGBClassifier()
selector = RFE(model, n_features_to_select=top_n_features, step=1)
selector = selector.fit(X, y)
X_imp=None
X_imp=c6[X.columns[(selector.get_support())]]
print("Top features are\n")
for val in X.columns[selector.ranking_.argsort()][:10].to_list():
    print(val)


for i in X_imp.columns:
    plt.figure(frameon=False)
    sns.boxplot(x=y,y=X[i],data=X)
# Out:
# 1    409
# 0    409
# Name: class, dtype: int64
# Top features are
#
# q_% less than 18 years of age
# q_% Drive Alone to Work
# q_% Native Hawaiian/Other Pacific Islander
# q_High School Graduation Rate
# q_Suicide Rate (Age-Adjusted)
# q_Average Daily PM2.5
# q_% American Indian & Alaska Native
# q_countycode
# q_% Female
# q_% With Annual Mammogram
