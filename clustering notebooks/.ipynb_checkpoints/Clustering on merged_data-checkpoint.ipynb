# %% [markdown]
# ## Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import davies_bouldin_score

# %%
file=pd.read_csv('../data/merged_data.csv')

# %%
X=file.drop(columns=['Unnamed: 0',"FIPS","State","County","Presence of Water Violation","Other Primary Care Provider Ratio","countycode"],axis=1)

# %%
X.head()
# Out:
#    Deaths  Years of Potential Life Lost Rate  % Fair or Poor Health  \
# 0   791.0                        8128.591190              20.882987
# 1  2967.0                        7354.122530              17.509134
# 2   472.0                       10253.573403              29.591802
# 3   471.0                       11977.539484              19.439724
# 4  1085.0                       11335.071134              21.745293
#
#    Average Number of Physically Unhealthy Days  \
# 0                                     4.743889
# 1                                     4.224519
# 2                                     5.430279
# 3                                     4.591482
# 4                                     4.860808
#
#    Average Number of Mentally Unhealthy Days  % Low Birthweight  % Smokers  \
# 0                                   4.654031           8.619529  18.081557
# 1                                   4.304056           8.345003  17.489033
# 2                                   5.185594          11.474559  21.999985
# 3                                   4.551699          10.308710  19.114200
# 4                                   4.891455           7.604563  19.208672
#
#    Food Environment Index  % Physically Inactive  \
# 0                     7.2                   34.7
# 1                     8.0                   26.5
# 2                     5.6                   23.5
# 3                     7.8                   33.5
# 4                     8.4                   30.3
#
#    % With Access to Exercise Opportunities  ...  internet_nonconsumer  \
# 0                                69.130124  ...                 1.000
# 1                                73.713549  ...                 9.000
# 2                                53.166770  ...                 1.000
# 3                                16.251364  ...                 0.698
# 4                                15.634486  ...                 1.000
#
#    internet_all  internet_hhs  internet_ratio  covid_cases  covid_deaths  \
# 0          17.0        21.054           0.750         1241            23
# 1          80.0        76.133           0.920         3776            32
# 2           6.0         9.191           0.540          646             6
# 3           4.0         6.916           0.698          464             6
# 4          14.0        20.690           0.620          967             5
#
#    internet_percent  %  Adults with Obesity  Heart Disease Death Rate  \
# 0              75.0                    32.7                     388.7
# 1              92.0                    30.1                     362.6
# 2              54.0                    41.2                     444.3
# 3              69.8                    37.4                     491.8
# 4              62.0                    32.5                     437.9
#
#    Hypertension Death Rate
# 0                    179.6
# 1                    143.4
# 2                    217.2
# 3                    143.3
# 4                    112.4
#
# [5 rows x 81 columns]

# %%
X.shape
# Out:
# (3100, 81)

# %% [markdown]
# ### Column details

# %%
X.describe()
# Out:
#              Deaths  Years of Potential Life Lost Rate  % Fair or Poor Health  \
# count   3100.000000                        3100.000000            3100.000000
# mean    1200.589677                        7827.091920              17.941393
# std     3133.798963                        3436.128384               4.728566
# min        0.000000                           0.000000               8.120645
# 25%      178.000000                        6291.289478              14.330513
# 50%      409.000000                        8003.773251              17.230312
# 75%      976.500000                        9927.314540              20.925938
# max    84296.000000                       29138.378057              40.990687
#
#        Average Number of Physically Unhealthy Days  \
# count                                  3100.000000
# mean                                      3.991602
# std                                       0.702353
# min                                       2.449054
# 25%                                       3.475977
# 50%                                       3.936494
# 75%                                       4.441717
# max                                       6.552513
#
#        Average Number of Mentally Unhealthy Days  % Low Birthweight  \
# count                                3100.000000        3100.000000
# mean                                    4.170133           7.921836
# std                                     0.601551           2.414836
# min                                     2.532818           0.000000
# 25%                                     3.754056           6.692913
# 50%                                     4.175720           7.762506
# 75%                                     4.577316           9.041310
# max                                     6.313753          24.390244
#
#          % Smokers  Food Environment Index  % Physically Inactive  \
# count  3100.000000             3100.000000            3100.000000
# mean     17.482486                7.429032              27.388065
# std       3.569744                1.256604               5.705178
# min       5.908719                0.000000               9.500000
# 25%      14.976697                6.900000              23.600000
# 50%      16.982250                7.700000              27.200000
# 75%      19.756380                8.200000              31.100000
# max      41.491309               10.000000              49.900000
#
#        % With Access to Exercise Opportunities  ...  internet_nonconsumer  \
# count                              3100.000000  ...           3100.000000
# mean                                 62.925927  ...              2.746771
# std                                  23.252200  ...              9.712527
# min                                   0.000000  ...              0.000000
# 25%                                  48.576080  ...              0.000000
# 50%                                  65.996779  ...              1.000000
# 75%                                  80.155007  ...              2.000000
# max                                 100.000000  ...            305.000000
#
#        internet_all  internet_hhs  internet_ratio    covid_cases  \
# count   3100.000000   3100.000000     3100.000000    3100.000000
# mean      32.278817     37.524221        0.699828    1600.755806
# std      104.880206    112.298573        0.172544    6929.971719
# min        0.000000      0.152000        0.110000       1.000000
# 25%        3.000000      4.337500        0.610000      64.000000
# 50%        7.000000      9.948000        0.698000     230.000000
# 75%       20.000000     25.928250        0.780000     793.000000
# max     3054.000000   3295.198000        3.330000  214197.000000
#
#        covid_deaths  internet_percent  %  Adults with Obesity  \
# count   3100.000000       3100.000000             3100.000000
# mean      50.353226         69.982839               33.483290
# std      268.364932         17.254354                5.903441
# min        0.000000         11.000000               11.000000
# 25%        1.000000         61.000000               29.700000
# 50%        4.000000         69.800000               33.700000
# 75%       18.000000         78.000000               37.325000
# max     5973.000000        333.000000               58.900000
#
#        Heart Disease Death Rate  Hypertension Death Rate
# count               3100.000000              3100.000000
# mean                 357.333387               255.347774
# std                   85.357226               108.623032
# min                   -1.000000                -1.000000
# 25%                  298.275000               181.300000
# 50%                  345.000000               236.000000
# 75%                  403.800000               302.925000
# max                  970.800000              1136.300000
#
# [8 rows x 81 columns]

# %%
# Checking for presence of null values in any column

null_col=X.columns[X.isnull().any()].tolist()  
if len(null_col)>0:
    print(null_col)
else:
    print(" No null columns found")
# Out:
#  No null columns found

# %%
for val in null_col:
    print("The {} column has {} missing values".format(val,X[val].isnull().sum()))

# %%
X=X.dropna()

# %%
#listing all the columns with type str
for val in X.columns:
    if type(X[val][0])==str:
        print(val)

# %% [markdown]
# # Variance threshold to drop low variance data

# %%
def Drop(l1, l2): 
    dif = [i for i in l1  if i not in l2] 
    return dif

# %%
feature_drop={}

for th in range(0,50,5):
    thresh = VarianceThreshold(threshold=th)
    thresh.fit(X)
    dropped_list=Drop(X.columns.tolist(),X.columns[thresh.get_support()].tolist())
    feature_drop[th]=(dropped_list,len(dropped_list))
    print("For threshold of {} the number of features dropped are {}".format(th,len(dropped_list)))
# Out:
# For threshold of 0 the number of features dropped are 0
# For threshold of 5 the number of features dropped are 11
# For threshold of 10 the number of features dropped are 16
# For threshold of 15 the number of features dropped are 21
# For threshold of 20 the number of features dropped are 25
# For threshold of 25 the number of features dropped are 28
# For threshold of 30 the number of features dropped are 28
# For threshold of 35 the number of features dropped are 32
# For threshold of 40 the number of features dropped are 33
# For threshold of 45 the number of features dropped are 33

# %% [markdown]
# ##### Since data is normalized so it does not contain lagre variance

# %% [markdown]
# ###  [       { " Threshold Value" :  (  [ 'Dropped features']  ,  'number of dropped features')  }  , ..........  ]

# %%
feature_drop
# Out:
# {0: ([], 0),
#  5: (['Average Number of Physically Unhealthy Days',
#    'Average Number of Mentally Unhealthy Days',
#    'Food Environment Index',
#    '% Unemployed',
#    'Income Ratio',
#    'Average Daily PM2.5',
#    '% Frequent Mental Distress',
#    'Average Reading Performance',
#    'Average Math Performance',
#    '% Native Hawaiian/Other Pacific Islander',
#    'internet_ratio',
#    '% households wo car'],
#   12),
#  10: (['Average Number of Physically Unhealthy Days',
#    'Average Number of Mentally Unhealthy Days',
#    '% Low Birthweight',
#    'Food Environment Index',
#    '% Excessive Drinking',
#    '% Unemployed',
#    'Income Ratio',
#    'Average Daily PM2.5',
#    '% Frequent Mental Distress',
#    'Average Reading Performance',
#    'Average Math Performance',
#    '% Asian',
#    '% Native Hawaiian/Other Pacific Islander',
#    '% Not Proficient in English',
#    '% Female',
#    'internet_ratio',
#    '% households wo car',
#    '% Limited English Proficiency',
#    '% workers commuting by public transit',
#    '% Veterans in Civilian Adult Population'],
#   20),
#  15: (['Average Number of Physically Unhealthy Days',
#    'Average Number of Mentally Unhealthy Days',
#    '% Low Birthweight',
#    '% Smokers',
#    'Food Environment Index',
#    '% Excessive Drinking',
#    '% Unemployed',
#    'Income Ratio',
#    'Average Daily PM2.5',
#    'Infant Mortality Rate',
#    '% Frequent Mental Distress',
#    '% Children Uninsured',
#    'Average Reading Performance',
#    'Average Math Performance',
#    '% Severe Housing Cost Burden',
#    '% less than 18 years of age',
#    '% Asian',
#    '% Native Hawaiian/Other Pacific Islander',
#    '% Not Proficient in English',
#    '% Female',
#    'internet_ratio',
#    '% Diagnosed Diabetes',
#    '% households wo car',
#    '% Limited English Proficiency',
#    '% workers commuting by public transit',
#    '% Veterans in Civilian Adult Population'],
#   26),
#  20: (['Average Number of Physically Unhealthy Days',
#    'Average Number of Mentally Unhealthy Days',
#    '% Low Birthweight',
#    '% Smokers',
#    'Food Environment Index',
#    '% Excessive Drinking',
#    '% Unemployed',
#    'Income Ratio',
#    'Average Daily PM2.5',
#    '% Severe Housing Problems',
#    'Infant Mortality Rate',
#    '% Frequent Mental Distress',
#    '% Food Insecure',
#    '% Insufficient Sleep',
#    '% Children Uninsured',
#    'Average Reading Performance',
#    'Average Math Performance',
#    '% Severe Housing Cost Burden',
#    '% less than 18 years of age',
#    '% Asian',
#    '% Native Hawaiian/Other Pacific Islander',
#    '% Not Proficient in English',
#    '% Female',
#    'internet_ratio',
#    '% Diagnosed Diabetes',
#    '% households wo car',
#    '% disabled',
#    '% Limited English Proficiency',
#    '% workers commuting by public transit',
#    '% Veterans in Civilian Adult Population'],
#   30),
#  25: (['% Fair or Poor Health',
#    'Average Number of Physically Unhealthy Days',
#    'Average Number of Mentally Unhealthy Days',
#    '% Low Birthweight',
#    '% Smokers',
#    'Food Environment Index',
#    '% Excessive Drinking',
#    '% Unemployed',
#    'Income Ratio',
#    'Average Daily PM2.5',
#    '% Severe Housing Problems',
#    'Infant Mortality Rate',
#    '% Frequent Mental Distress',
#    '% Food Insecure',
#    '% Insufficient Sleep',
#    '% Children Uninsured',
#    'Average Reading Performance',
#    'Average Math Performance',
#    'Homicide Rate',
#    '% Severe Housing Cost Burden',
#    '% less than 18 years of age',
#    '% Asian',
#    '% Native Hawaiian/Other Pacific Islander',
#    '% Not Proficient in English',
#    '% Female',
#    'internet_ratio',
#    '% Adults 65 and Older',
#    '% Diagnosed Diabetes',
#    '% households wo car',
#    '% disabled',
#    '% Limited English Proficiency',
#    '% workers commuting by public transit',
#    '% Veterans in Civilian Adult Population'],
#   33),
#  30: (['% Fair or Poor Health',
#    'Average Number of Physically Unhealthy Days',
#    'Average Number of Mentally Unhealthy Days',
#    '% Low Birthweight',
#    '% Smokers',
#    'Food Environment Index',
#    '% Excessive Drinking',
#    '% Unemployed',
#    'Income Ratio',
#    'Average Daily PM2.5',
#    '% Severe Housing Problems',
#    'Infant Mortality Rate',
#    '% Frequent Mental Distress',
#    '% Food Insecure',
#    '% Insufficient Sleep',
#    '% Children Uninsured',
#    'Average Reading Performance',
#    'Average Math Performance',
#    'Homicide Rate',
#    '% Severe Housing Cost Burden',
#    '% less than 18 years of age',
#    '% Asian',
#    '% Native Hawaiian/Other Pacific Islander',
#    '% Not Proficient in English',
#    '% Female',
#    'internet_ratio',
#    '% Adults 65 and Older',
#    '% Diagnosed Diabetes',
#    '% households wo car',
#    'Number of Hospitals',
#    '% disabled',
#    '% Without Health Insurance',
#    '% Limited English Proficiency',
#    '% workers commuting by public transit',
#    '% Veterans in Civilian Adult Population'],
#   35),
#  35: (['% Fair or Poor Health',
#    'Average Number of Physically Unhealthy Days',
#    'Average Number of Mentally Unhealthy Days',
#    '% Low Birthweight',
#    '% Smokers',
#    'Food Environment Index',
#    '% Physically Inactive',
#    '% Excessive Drinking',
#    '% Unemployed',
#    'Income Ratio',
#    'Social Association Rate',
#    'Average Daily PM2.5',
#    '% Severe Housing Problems',
#    'Infant Mortality Rate',
#    '% Frequent Mental Distress',
#    '% Food Insecure',
#    '% Insufficient Sleep',
#    '% Children Uninsured',
#    '% Disconnected Youth',
#    'Average Reading Performance',
#    'Average Math Performance',
#    'Homicide Rate',
#    '% Severe Housing Cost Burden',
#    '% less than 18 years of age',
#    '% Asian',
#    '% Native Hawaiian/Other Pacific Islander',
#    '% Not Proficient in English',
#    '% Female',
#    'internet_ratio',
#    '%  Adults with Obesity',
#    '% Adults 65 and Older',
#    '% Diagnosed Diabetes',
#    '% households wo car',
#    'Number of Hospitals',
#    '% disabled',
#    '% Without Health Insurance',
#    '% Limited English Proficiency',
#    '% workers commuting by public transit',
#    '% Veterans in Civilian Adult Population'],
#   39),
#  40: (['% Fair or Poor Health',
#    'Average Number of Physically Unhealthy Days',
#    'Average Number of Mentally Unhealthy Days',
#    '% Low Birthweight',
#    '% Smokers',
#    'Food Environment Index',
#    '% Physically Inactive',
#    '% Excessive Drinking',
#    '% Unemployed',
#    'Income Ratio',
#    'Social Association Rate',
#    'Average Daily PM2.5',
#    '% Severe Housing Problems',
#    'Infant Mortality Rate',
#    '% Frequent Mental Distress',
#    '% Food Insecure',
#    '% Insufficient Sleep',
#    '% Children Uninsured',
#    '% Disconnected Youth',
#    'Average Reading Performance',
#    'Average Math Performance',
#    'Homicide Rate',
#    '% Severe Housing Cost Burden',
#    '% less than 18 years of age',
#    '% Asian',
#    '% Native Hawaiian/Other Pacific Islander',
#    '% Not Proficient in English',
#    '% Female',
#    'internet_ratio',
#    '%  Adults with Obesity',
#    '% Adults 65 and Older',
#    '% Diagnosed Diabetes',
#    '% households wo car',
#    'Number of Hospitals',
#    '% disabled',
#    '% Without Health Insurance',
#    '% Limited English Proficiency',
#    '% workers commuting by public transit',
#    '% Veterans in Civilian Adult Population'],
#   39),
#  45: (['% Fair or Poor Health',
#    'Average Number of Physically Unhealthy Days',
#    'Average Number of Mentally Unhealthy Days',
#    '% Low Birthweight',
#    '% Smokers',
#    'Food Environment Index',
#    '% Physically Inactive',
#    '% Excessive Drinking',
#    '% Unemployed',
#    'Income Ratio',
#    'Social Association Rate',
#    'Average Daily PM2.5',
#    '% Severe Housing Problems',
#    'Infant Mortality Rate',
#    '% Frequent Mental Distress',
#    '% Food Insecure',
#    '% Insufficient Sleep',
#    '% Children Uninsured',
#    '% Disconnected Youth',
#    'Average Reading Performance',
#    'Average Math Performance',
#    'Homicide Rate',
#    '% Severe Housing Cost Burden',
#    '% less than 18 years of age',
#    '% Asian',
#    '% Native Hawaiian/Other Pacific Islander',
#    '% Not Proficient in English',
#    '% Female',
#    'internet_ratio',
#    '%  Adults with Obesity',
#    '% Adults 65 and Older',
#    '% Diagnosed Diabetes',
#    '% households wo car',
#    'Number of Hospitals',
#    '% disabled',
#    '% Without Health Insurance',
#    '% Limited English Proficiency',
#    '% workers commuting by public transit',
#    '% Veterans in Civilian Adult Population'],
#   39)}

# %%
thresh.variances_
# Out:
# array([1.03400119e+07, 1.20978555e+07, 2.23019811e+01, 4.93176656e-01,
#        3.62235681e-01, 6.09073958e+00, 1.27393274e+01, 1.59991938e+00,
#        3.24518018e+01, 5.47028168e+02, 9.91426959e+00, 2.29442704e+02,
#        8.34992831e+04, 2.31055280e+02, 1.32114050e+03, 1.02473614e+03,
#        6.61871319e+01, 1.02364821e+02, 2.69233590e+02, 1.39314084e+02,
#        2.13083614e+00, 7.86965735e+01, 5.81622573e-01, 1.13008320e+02,
#        3.47238215e+01, 3.83934168e+04, 8.46756143e+02, 4.58818723e+00,
#        1.95664505e+01, 5.49473372e+01, 1.55717531e+02, 1.36299482e+02,
#        1.54795622e+04, 1.24433332e+03, 1.32060237e+01, 3.87970209e+00,
#        3.73383255e+04, 1.55813593e+01, 6.72625252e+01, 2.10004510e+02,
#        1.16524285e+02, 1.73021813e+01, 1.33551058e+01, 3.25220547e+01,
#        1.54940700e+00, 1.59471961e+00, 1.92618489e+08, 4.38815984e+02,
#        6.35162106e+02, 2.47416756e+02, 2.02194134e+01, 1.03874283e+02,
#        8.44055375e+01, 3.87976466e+02, 6.66787982e+01, 1.28528584e+01,
#        1.11405794e+11, 1.17128591e+01, 2.04741969e+02, 5.37894050e+01,
#        8.72400434e+00, 1.80649431e-01, 1.89413131e+02, 4.01685352e+02,
#        7.74850910e+00, 5.18444814e+00, 9.92579806e+02, 9.23938654e+03,
#        9.69392897e+01, 1.15487145e+04, 1.31956797e+04, 3.04201862e-02,
#        1.33929234e+08, 1.03585519e+05, 3.04201862e+02, 3.49239466e+01,
#        7.24739150e+03, 1.17323113e+04, 2.27838878e+01, 2.61757849e+02,
#        1.23908421e+01, 2.78881917e+02, 6.93156489e-03, 2.84644527e+01,
#        1.93886954e+01, 2.53991619e+01, 9.60597752e+00, 9.46735061e+00,
#        7.07012688e+00, 8.84299564e+03])

# %%
thresh.get_support()
# Out:
# array([ True,  True, False, False, False, False, False, False, False,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True, False,  True, False,  True,  True,
#        False, False,  True,  True,  True,  True,  True, False, False,
#         True, False,  True,  True,  True, False, False, False, False,
#        False,  True,  True,  True,  True, False,  True,  True,  True,
#         True, False,  True, False,  True,  True, False, False,  True,
#         True, False, False,  True,  True,  True,  True,  True, False,
#         True,  True,  True, False,  True,  True, False,  True, False,
#         True, False, False, False, False, False, False, False,  True])

# %%
thresh.variances_
# Out:
# array([1.03400119e+07, 1.20978555e+07, 2.23019811e+01, 4.93176656e-01,
#        3.62235681e-01, 6.09073958e+00, 1.27393274e+01, 1.59991938e+00,
#        3.24518018e+01, 5.47028168e+02, 9.91426959e+00, 2.29442704e+02,
#        8.34992831e+04, 2.31055280e+02, 1.32114050e+03, 1.02473614e+03,
#        6.61871319e+01, 1.02364821e+02, 2.69233590e+02, 1.39314084e+02,
#        2.13083614e+00, 7.86965735e+01, 5.81622573e-01, 1.13008320e+02,
#        3.47238215e+01, 3.83934168e+04, 8.46756143e+02, 4.58818723e+00,
#        1.95664505e+01, 5.49473372e+01, 1.55717531e+02, 1.36299482e+02,
#        1.54795622e+04, 1.24433332e+03, 1.32060237e+01, 3.87970209e+00,
#        3.73383255e+04, 1.55813593e+01, 6.72625252e+01, 2.10004510e+02,
#        1.16524285e+02, 1.73021813e+01, 1.33551058e+01, 3.25220547e+01,
#        1.54940700e+00, 1.59471961e+00, 1.92618489e+08, 4.38815984e+02,
#        6.35162106e+02, 2.47416756e+02, 2.02194134e+01, 1.03874283e+02,
#        8.44055375e+01, 3.87976466e+02, 6.66787982e+01, 1.28528584e+01,
#        1.11405794e+11, 1.17128591e+01, 2.04741969e+02, 5.37894050e+01,
#        8.72400434e+00, 1.80649431e-01, 1.89413131e+02, 4.01685352e+02,
#        7.74850910e+00, 5.18444814e+00, 9.92579806e+02, 9.23938654e+03,
#        9.69392897e+01, 1.15487145e+04, 1.31956797e+04, 3.04201862e-02,
#        1.33929234e+08, 1.03585519e+05, 3.04201862e+02, 3.49239466e+01,
#        7.24739150e+03, 1.17323113e+04, 2.27838878e+01, 2.61757849e+02,
#        1.23908421e+01, 2.78881917e+02, 6.93156489e-03, 2.84644527e+01,
#        1.93886954e+01, 2.53991619e+01, 9.60597752e+00, 9.46735061e+00,
#        7.07012688e+00, 8.84299564e+03])

# %% [markdown]
# # Correlation Matrix

# %%
X
# Out:
#       Deaths  Years of Potential Life Lost Rate  % Fair or Poor Health  \
# 0      791.0                        8128.591190              20.882987
# 1     2967.0                        7354.122530              17.509134
# 2      472.0                       10253.573403              29.591802
# 3      471.0                       11977.539484              19.439724
# 4     1085.0                       11335.071134              21.745293
# ...      ...                                ...                    ...
# 3131   532.0                        7831.827655              14.813082
# 3132   109.0                        2730.603992              11.914358
# 3133   256.0                        7330.683549              15.537464
# 3134   110.0                        6586.049959              15.955971
# 3135    89.0                        5388.706947              13.934025
#
#       Average Number of Physically Unhealthy Days  \
# 0                                        4.743889
# 1                                        4.224519
# 2                                        5.430279
# 3                                        4.591482
# 4                                        4.860808
# ...                                           ...
# 3131                                     3.402029
# 3132                                     3.031233
# 3133                                     3.628488
# 3134                                     3.613308
# 3135                                     3.463619
#
#       Average Number of Mentally Unhealthy Days  % Low Birthweight  % Smokers  \
# 0                                      4.654031           8.619529  18.081557
# 1                                      4.304056           8.345003  17.489033
# 2                                      5.185594          11.474559  21.999985
# 3                                      4.551699          10.308710  19.114200
# 4                                      4.891455           7.604563  19.208672
# ...                                         ...                ...        ...
# 3131                                   3.623554           9.705248  18.073422
# 3132                                   3.180613           7.736721  14.546369
# 3133                                   3.669805          10.110206  17.212675
# 3134                                   3.682514           7.028754  16.859400
# 3135                                   3.660440           6.589147  16.693134
#
#       Food Environment Index  % Physically Inactive  \
# 0                        7.2                   34.7
# 1                        8.0                   26.5
# 2                        5.6                   23.5
# 3                        7.8                   33.5
# 4                        8.4                   30.3
# ...                      ...                    ...
# 3131                     7.7                   25.0
# 3132                     8.2                   11.6
# 3133                     7.4                   27.2
# 3134                     8.3                   28.2
# 3135                     7.9                   26.9
#
#       % With Access to Exercise Opportunities  ...  % Diagnosed Diabetes  \
# 0                                   69.130124  ...                  11.4
# 1                                   73.713549  ...                   8.2
# 2                                   53.166770  ...                  15.1
# 3                                   16.251364  ...                  12.2
# 4                                   15.634486  ...                  12.2
# ...                                       ...  ...                   ...
# 3131                                89.686344  ...                   8.0
# 3132                                99.718230  ...                   2.2
# 3133                                84.018373  ...                   9.5
# 3134                                83.182937  ...                   8.2
# 3135                                63.027192  ...                   9.2
#
#       % Nonwhite  % households wo car  Number of Hospitals  % disabled  \
# 0      23.121377             0.056569                  1.0        19.3
# 1      13.733800             0.035530                  4.0        14.0
# 2      52.618106             0.092373                  1.0        22.2
# 3      23.345319             0.059283                  1.0        16.7
# 4       4.494752             0.041373                  1.0        14.2
# ...          ...                  ...                  ...         ...
# 3131    6.874901             0.023849                  2.0        12.3
# 3132    9.657834             0.024787                  1.0         7.0
# 3133    6.584502             0.039195                  2.0        17.2
# 3134   10.284168             0.049284                  1.0        14.9
# 3135    7.464789             0.025456                  1.0        14.4
#
#       % Without Health Insurance  % Limited English Proficiency  \
# 0                           10.0                       0.653564
# 1                           13.2                       1.424538
# 2                           13.5                       1.469628
# 3                           10.6                       0.687135
# 4                           14.1                       1.461165
# ...                          ...                            ...
# 3131                        11.5                       2.400605
# 3132                        13.4                       5.033850
# 3133                        11.8                       0.439560
# 3134                        14.8                       1.285798
# 3135                        12.7                       2.122796
#
#       % workers commuting by public transit  \
# 0                                       0.1
# 1                                       0.1
# 2                                       0.3
# 3                                       0.5
# 4                                       0.1
# ...                                     ...
# 3131                                    2.5
# 3132                                    4.1
# 3133                                    3.6
# 3134                                    0.0
# 3135                                    8.3
#
#       % Veterans in Civilian Adult Population  opioid death rate
# 0                                      12.283           8.992644
# 1                                      11.938           6.421370
# 2                                       7.672          20.095655
# 3                                       7.152          22.321429
# 4                                       8.532           8.644537
# ...                                       ...                ...
# 3131                                    8.256          11.614132
# 3132                                    5.283          21.662840
# 3133                                    7.919          24.631755
# 3134                                   12.006          63.411541
# 3135                                   10.849          71.766901
#
# [3135 rows x 90 columns]

# %%
Correlation_Matrix=X.corr().abs()
Correlation_Matrix
# Out:
#                                                Deaths  \
# Deaths                                       1.000000
# Years of Potential Life Lost Rate            0.017668
# % Fair or Poor Health                        0.048258
# Average Number of Physically Unhealthy Days  0.064390
# Average Number of Mentally Unhealthy Days    0.031253
# ...                                               ...
# % Without Health Insurance                   0.064588
# % Limited English Proficiency                0.257600
# % workers commuting by public transit        0.374184
# % Veterans in Civilian Adult Population      0.141652
# opioid death rate                            0.127265
#
#                                              Years of Potential Life Lost Rate  \
# Deaths                                                                0.017668
# Years of Potential Life Lost Rate                                     1.000000
# % Fair or Poor Health                                                 0.582578
# Average Number of Physically Unhealthy Days                           0.638061
# Average Number of Mentally Unhealthy Days                             0.629518
# ...                                                                        ...
# % Without Health Insurance                                            0.125869
# % Limited English Proficiency                                         0.141659
# % workers commuting by public transit                                 0.092309
# % Veterans in Civilian Adult Population                               0.040213
# opioid death rate                                                     0.433403
#
#                                              % Fair or Poor Health  \
# Deaths                                                    0.048258
# Years of Potential Life Lost Rate                         0.582578
# % Fair or Poor Health                                     1.000000
# Average Number of Physically Unhealthy Days               0.890488
# Average Number of Mentally Unhealthy Days                 0.781539
# ...                                                            ...
# % Without Health Insurance                                0.443405
# % Limited English Proficiency                             0.224938
# % workers commuting by public transit                     0.088476
# % Veterans in Civilian Adult Population                   0.227008
# opioid death rate                                         0.079618
#
#                                              Average Number of Physically Unhealthy Days  \
# Deaths                                                                          0.064390
# Years of Potential Life Lost Rate                                               0.638061
# % Fair or Poor Health                                                           0.890488
# Average Number of Physically Unhealthy Days                                     1.000000
# Average Number of Mentally Unhealthy Days                                       0.934777
# ...                                                                                  ...
# % Without Health Insurance                                                      0.251959
# % Limited English Proficiency                                                   0.007197
# % workers commuting by public transit                                           0.117510
# % Veterans in Civilian Adult Population                                         0.103709
# opioid death rate                                                               0.137101
#
#                                              Average Number of Mentally Unhealthy Days  \
# Deaths                                                                        0.031253
# Years of Potential Life Lost Rate                                             0.629518
# % Fair or Poor Health                                                         0.781539
# Average Number of Physically Unhealthy Days                                   0.934777
# Average Number of Mentally Unhealthy Days                                     1.000000
# ...                                                                                ...
# % Without Health Insurance                                                    0.139722
# % Limited English Proficiency                                                 0.086688
# % workers commuting by public transit                                         0.102415
# % Veterans in Civilian Adult Population                                       0.061498
# opioid death rate                                                             0.185305
#
#                                              % Low Birthweight  % Smokers  \
# Deaths                                                0.064277   0.135838
# Years of Potential Life Lost Rate                     0.552171   0.649520
# % Fair or Poor Health                                 0.544668   0.727620
# Average Number of Physically Unhealthy Days           0.501794   0.811583
# Average Number of Mentally Unhealthy Days             0.497009   0.759802
# ...                                                        ...        ...
# % Without Health Insurance                            0.115840   0.109624
# % Limited English Proficiency                         0.053443   0.221769
# % workers commuting by public transit                 0.013877   0.158642
# % Veterans in Civilian Adult Population               0.129225   0.069072
# opioid death rate                                     0.421880   0.127384
#
#                                              Food Environment Index  \
# Deaths                                                     0.075702
# Years of Potential Life Lost Rate                          0.257664
# % Fair or Poor Health                                      0.503002
# Average Number of Physically Unhealthy Days                0.465234
# Average Number of Mentally Unhealthy Days                  0.379918
# ...                                                             ...
# % Without Health Insurance                                 0.322122
# % Limited English Proficiency                              0.005760
# % workers commuting by public transit                      0.077048
# % Veterans in Civilian Adult Population                    0.039396
# opioid death rate                                          0.226546
#
#                                              % Physically Inactive  \
# Deaths                                                    0.188870
# Years of Potential Life Lost Rate                         0.409530
# % Fair or Poor Health                                     0.539380
# Average Number of Physically Unhealthy Days               0.496070
# Average Number of Mentally Unhealthy Days                 0.464023
# ...                                                            ...
# % Without Health Insurance                                0.248698
# % Limited English Proficiency                             0.164389
# % workers commuting by public transit                     0.199775
# % Veterans in Civilian Adult Population                   0.028412
# opioid death rate                                         0.003593
#
#                                              % With Access to Exercise Opportunities  \
# Deaths                                                                      0.301847
# Years of Potential Life Lost Rate                                           0.137928
# % Fair or Poor Health                                                       0.334101
# Average Number of Physically Unhealthy Days                                 0.287168
# Average Number of Mentally Unhealthy Days                                   0.229085
# ...                                                                              ...
# % Without Health Insurance                                                  0.273537
# % Limited English Proficiency                                               0.147431
# % workers commuting by public transit                                       0.250398
# % Veterans in Civilian Adult Population                                     0.004343
# opioid death rate                                                           0.299887
#
#                                              ...  % Diagnosed Diabetes  \
# Deaths                                       ...              0.059975
# Years of Potential Life Lost Rate            ...              0.488329
# % Fair or Poor Health                        ...              0.541336
# Average Number of Physically Unhealthy Days  ...              0.508280
# Average Number of Mentally Unhealthy Days    ...              0.477970
# ...                                          ...                   ...
# % Without Health Insurance                   ...              0.185023
# % Limited English Proficiency                ...              0.081154
# % workers commuting by public transit        ...              0.105182
# % Veterans in Civilian Adult Population      ...              0.083517
# opioid death rate                            ...              0.153263
#
#                                              % Nonwhite  % households wo car  \
# Deaths                                         0.212077             0.087604
# Years of Potential Life Lost Rate              0.354289             0.099481
# % Fair or Poor Health                          0.470858             0.171209
# Average Number of Physically Unhealthy Days    0.310350             0.169524
# Average Number of Mentally Unhealthy Days      0.228536             0.131455
# ...                                                 ...                  ...
# % Without Health Insurance                     0.264568             0.027822
# % Limited English Proficiency                  0.150473             0.058155
# % workers commuting by public transit          0.208463             0.245539
# % Veterans in Civilian Adult Population        0.202993             0.122133
# opioid death rate                              0.110768             0.011949
#
#                                              Number of Hospitals  % disabled  \
# Deaths                                                  0.931877    0.203973
# Years of Potential Life Lost Rate                       0.029873    0.412710
# % Fair or Poor Health                                   0.054128    0.521927
# Average Number of Physically Unhealthy Days             0.079366    0.613901
# Average Number of Mentally Unhealthy Days               0.053748    0.606103
# ...                                                          ...         ...
# % Without Health Insurance                              0.045564    0.168946
# % Limited English Proficiency                           0.258513    0.196269
# % workers commuting by public transit                   0.323218    0.219184
# % Veterans in Civilian Adult Population                 0.152954    0.215238
# opioid death rate                                       0.129871    0.033935
#
#                                              % Without Health Insurance  \
# Deaths                                                         0.064588
# Years of Potential Life Lost Rate                              0.125869
# % Fair or Poor Health                                          0.443405
# Average Number of Physically Unhealthy Days                    0.251959
# Average Number of Mentally Unhealthy Days                      0.139722
# ...                                                                 ...
# % Without Health Insurance                                     1.000000
# % Limited English Proficiency                                  0.378972
# % workers commuting by public transit                          0.126058
# % Veterans in Civilian Adult Population                        0.077322
# opioid death rate                                              0.131284
#
#                                              % Limited English Proficiency  \
# Deaths                                                            0.257600
# Years of Potential Life Lost Rate                                 0.141659
# % Fair or Poor Health                                             0.224938
# Average Number of Physically Unhealthy Days                       0.007197
# Average Number of Mentally Unhealthy Days                         0.086688
# ...                                                                    ...
# % Without Health Insurance                                        0.378972
# % Limited English Proficiency                                     1.000000
# % workers commuting by public transit                             0.263094
# % Veterans in Civilian Adult Population                           0.319498
# opioid death rate                                                 0.017323
#
#                                              % workers commuting by public transit  \
# Deaths                                                                    0.374184
# Years of Potential Life Lost Rate                                         0.092309
# % Fair or Poor Health                                                     0.088476
# Average Number of Physically Unhealthy Days                               0.117510
# Average Number of Mentally Unhealthy Days                                 0.102415
# ...                                                                            ...
# % Without Health Insurance                                                0.126058
# % Limited English Proficiency                                             0.263094
# % workers commuting by public transit                                     1.000000
# % Veterans in Civilian Adult Population                                   0.201790
# opioid death rate                                                         0.061456
#
#                                              % Veterans in Civilian Adult Population  \
# Deaths                                                                      0.141652
# Years of Potential Life Lost Rate                                           0.040213
# % Fair or Poor Health                                                       0.227008
# Average Number of Physically Unhealthy Days                                 0.103709
# Average Number of Mentally Unhealthy Days                                   0.061498
# ...                                                                              ...
# % Without Health Insurance                                                  0.077322
# % Limited English Proficiency                                               0.319498
# % workers commuting by public transit                                       0.201790
# % Veterans in Civilian Adult Population                                     1.000000
# opioid death rate                                                           0.006243
#
#                                              opioid death rate
# Deaths                                                0.127265
# Years of Potential Life Lost Rate                     0.433403
# % Fair or Poor Health                                 0.079618
# Average Number of Physically Unhealthy Days           0.137101
# Average Number of Mentally Unhealthy Days             0.185305
# ...                                                        ...
# % Without Health Insurance                            0.131284
# % Limited English Proficiency                         0.017323
# % workers commuting by public transit                 0.061456
# % Veterans in Civilian Adult Population               0.006243
# opioid death rate                                     1.000000
#
# [90 rows x 90 columns]

# %%
# import seaborn as sn
# import matplotlib.pyplot as plt
# plt.figure(figsize=[256,256],dpi=100)
# sn.heatmap(Correlation_Matrix, annot=True)
# # plt.savefig('heatmap.png')
# plt.show()

# %% [markdown]
# ## Simulating feature drop based on correlation matrix

# %%
# Select upper triangle of correlation matrix

feat_drop_corr=[]

for i in range(50,100,5):
    d={}
    coff=(i/100)
    upper = Correlation_Matrix.where(np.triu(np.ones(Correlation_Matrix.shape), k=1).astype(np.bool))

    # Find features with correlation greater than some value
    to_drop = [column for column in upper.columns if any(upper[column] > coff)]

    # Drop features 
    X_new=X.drop(to_drop, axis=1, inplace=False)
    d[coff]=X_new.shape[-1] , to_drop
    feat_drop_corr.append(d)

# %%
feat_drop_corr
# Out:
# [{0.5: (33,
#    ['% Fair or Poor Health',
#     'Average Number of Physically Unhealthy Days',
#     'Average Number of Mentally Unhealthy Days',
#     '% Low Birthweight',
#     '% Smokers',
#     'Food Environment Index',
#     '% Physically Inactive',
#     '% Excessive Drinking',
#     'Teen Birth Rate',
#     'Dentist Rate',
#     '% Vaccinated',
#     '% Some College',
#     '% Unemployed',
#     '% Children in Poverty',
#     'Income Ratio',
#     '% Single-Parent Households',
#     'Injury Death Rate',
#     '% Drive Alone to Work',
#     'Age-Adjusted Death Rate',
#     'Infant Mortality Rate',
#     '% Frequent Mental Distress',
#     '% Food Insecure',
#     '% Limited Access to Healthy Foods',
#     'Motor Vehicle Mortality Rate',
#     '% Insufficient Sleep',
#     'Average Math Performance',
#     'Median Household Income',
#     '% Enrolled in Free or Reduced Lunch',
#     'non-White/White Segregation Index',
#     'Homicide Rate',
#     'Firearm Fatalities Rate',
#     '% Homeowners',
#     '% Severe Housing Cost Burden',
#     'Population',
#     '% Black',
#     '% Non-Hispanic White',
#     '% Not Proficient in English',
#     '% Rural',
#     'internet_consumer',
#     'internet_nonconsumer',
#     'internet_all',
#     'internet_hhs',
#     'covid_cases',
#     'covid_deaths',
#     'internet_percent',
#     '%  Adults with Obesity',
#     'Heart Disease Death Rate',
#     '% Adults 65 and Older',
#     'COPD Mortality Rate',
#     '% Diagnosed Diabetes',
#     '% Nonwhite',
#     'Number of Hospitals',
#     '% disabled',
#     '% Without Health Insurance',
#     '% Limited English Proficiency',
#     '% workers commuting by public transit',
#     'opioid death rate'])},
#  {0.55: (44,
#    ['% Fair or Poor Health',
#     'Average Number of Physically Unhealthy Days',
#     'Average Number of Mentally Unhealthy Days',
#     '% Low Birthweight',
#     '% Smokers',
#     '% Excessive Drinking',
#     'Teen Birth Rate',
#     '% Some College',
#     '% Unemployed',
#     '% Children in Poverty',
#     'Income Ratio',
#     '% Single-Parent Households',
#     'Age-Adjusted Death Rate',
#     '% Frequent Mental Distress',
#     '% Food Insecure',
#     '% Limited Access to Healthy Foods',
#     'Motor Vehicle Mortality Rate',
#     '% Insufficient Sleep',
#     'Average Math Performance',
#     'Median Household Income',
#     '% Enrolled in Free or Reduced Lunch',
#     'Firearm Fatalities Rate',
#     '% Homeowners',
#     '% Severe Housing Cost Burden',
#     'Population',
#     '% Black',
#     '% Non-Hispanic White',
#     '% Not Proficient in English',
#     '% Rural',
#     'internet_consumer',
#     'internet_nonconsumer',
#     'internet_all',
#     'internet_hhs',
#     'covid_cases',
#     'covid_deaths',
#     'internet_percent',
#     'Heart Disease Death Rate',
#     '% Adults 65 and Older',
#     'COPD Mortality Rate',
#     '% Nonwhite',
#     'Number of Hospitals',
#     '% disabled',
#     '% Without Health Insurance',
#     '% Limited English Proficiency',
#     '% workers commuting by public transit',
#     'opioid death rate'])},
#  {0.6: (52,
#    ['Average Number of Physically Unhealthy Days',
#     'Average Number of Mentally Unhealthy Days',
#     '% Smokers',
#     '% Excessive Drinking',
#     'Teen Birth Rate',
#     '% Some College',
#     '% Children in Poverty',
#     '% Single-Parent Households',
#     'Age-Adjusted Death Rate',
#     '% Frequent Mental Distress',
#     '% Food Insecure',
#     '% Limited Access to Healthy Foods',
#     'Motor Vehicle Mortality Rate',
#     '% Insufficient Sleep',
#     'Average Math Performance',
#     'Median Household Income',
#     '% Enrolled in Free or Reduced Lunch',
#     'Firearm Fatalities Rate',
#     '% Severe Housing Cost Burden',
#     'Population',
#     '% Black',
#     '% Non-Hispanic White',
#     '% Not Proficient in English',
#     'internet_consumer',
#     'internet_nonconsumer',
#     'internet_all',
#     'internet_hhs',
#     'covid_cases',
#     'covid_deaths',
#     'internet_percent',
#     'Heart Disease Death Rate',
#     '% Nonwhite',
#     'Number of Hospitals',
#     '% disabled',
#     '% Without Health Insurance',
#     '% Limited English Proficiency',
#     '% workers commuting by public transit',
#     'opioid death rate'])},
#  {0.65: (59,
#    ['Average Number of Physically Unhealthy Days',
#     'Average Number of Mentally Unhealthy Days',
#     '% Smokers',
#     'Teen Birth Rate',
#     '% Some College',
#     '% Children in Poverty',
#     '% Single-Parent Households',
#     'Age-Adjusted Death Rate',
#     '% Frequent Mental Distress',
#     '% Food Insecure',
#     '% Insufficient Sleep',
#     'Average Math Performance',
#     'Median Household Income',
#     '% Severe Housing Cost Burden',
#     'Population',
#     '% Black',
#     '% Not Proficient in English',
#     'internet_consumer',
#     'internet_nonconsumer',
#     'internet_all',
#     'internet_hhs',
#     'covid_cases',
#     'covid_deaths',
#     'internet_percent',
#     'Heart Disease Death Rate',
#     '% Nonwhite',
#     'Number of Hospitals',
#     '% disabled',
#     '% Without Health Insurance',
#     '% Limited English Proficiency',
#     'opioid death rate'])},
#  {0.7: (64,
#    ['Average Number of Physically Unhealthy Days',
#     'Average Number of Mentally Unhealthy Days',
#     '% Smokers',
#     'Teen Birth Rate',
#     '% Children in Poverty',
#     'Age-Adjusted Death Rate',
#     '% Frequent Mental Distress',
#     '% Food Insecure',
#     '% Insufficient Sleep',
#     'Average Math Performance',
#     'Median Household Income',
#     '% Severe Housing Cost Burden',
#     'Population',
#     '% Not Proficient in English',
#     'internet_consumer',
#     'internet_nonconsumer',
#     'internet_all',
#     'internet_hhs',
#     'covid_cases',
#     'covid_deaths',
#     'internet_percent',
#     '% Nonwhite',
#     'Number of Hospitals',
#     '% Without Health Insurance',
#     '% Limited English Proficiency',
#     'opioid death rate'])},
#  {0.75: (68,
#    ['Average Number of Physically Unhealthy Days',
#     'Average Number of Mentally Unhealthy Days',
#     '% Smokers',
#     '% Children in Poverty',
#     'Age-Adjusted Death Rate',
#     '% Frequent Mental Distress',
#     '% Food Insecure',
#     'Average Math Performance',
#     'Median Household Income',
#     'Population',
#     '% Not Proficient in English',
#     'internet_consumer',
#     'internet_nonconsumer',
#     'internet_all',
#     'internet_hhs',
#     'covid_cases',
#     'covid_deaths',
#     'internet_percent',
#     '% Nonwhite',
#     'Number of Hospitals',
#     '% Without Health Insurance',
#     '% Limited English Proficiency'])},
#  {0.8: (72,
#    ['Average Number of Physically Unhealthy Days',
#     'Average Number of Mentally Unhealthy Days',
#     '% Smokers',
#     '% Children in Poverty',
#     '% Frequent Mental Distress',
#     'Average Math Performance',
#     'Population',
#     '% Not Proficient in English',
#     'internet_consumer',
#     'internet_nonconsumer',
#     'internet_all',
#     'internet_hhs',
#     'covid_cases',
#     'covid_deaths',
#     'internet_percent',
#     '% Nonwhite',
#     'Number of Hospitals',
#     '% Limited English Proficiency'])},
#  {0.85: (76,
#    ['Average Number of Physically Unhealthy Days',
#     'Average Number of Mentally Unhealthy Days',
#     '% Frequent Mental Distress',
#     'Average Math Performance',
#     'Population',
#     'internet_consumer',
#     'internet_nonconsumer',
#     'internet_all',
#     'internet_hhs',
#     'covid_cases',
#     'covid_deaths',
#     'internet_percent',
#     'Number of Hospitals',
#     '% Limited English Proficiency'])},
#  {0.9: (79,
#    ['Average Number of Mentally Unhealthy Days',
#     '% Frequent Mental Distress',
#     'Population',
#     'internet_consumer',
#     'internet_nonconsumer',
#     'internet_all',
#     'internet_hhs',
#     'covid_cases',
#     'internet_percent',
#     'Number of Hospitals',
#     '% Limited English Proficiency'])},
#  {0.95: (83,
#    ['% Frequent Mental Distress',
#     'Population',
#     'internet_consumer',
#     'internet_nonconsumer',
#     'internet_all',
#     'internet_hhs',
#     'internet_percent'])}]

# %% [markdown]
# ###  [       { " Threshold Value" : 'number of remaining features' (  [ 'Dropped features']  ,)  }  , ..........  ]

# %%
X_new
# Out:
#       Deaths  Years of Potential Life Lost Rate  % Fair or Poor Health  \
# 0      791.0                        8128.591190              20.882987
# 1     2967.0                        7354.122530              17.509134
# 2      472.0                       10253.573403              29.591802
# 3      471.0                       11977.539484              19.439724
# 4     1085.0                       11335.071134              21.745293
# ...      ...                                ...                    ...
# 3131   532.0                        7831.827655              14.813082
# 3132   109.0                        2730.603992              11.914358
# 3133   256.0                        7330.683549              15.537464
# 3134   110.0                        6586.049959              15.955971
# 3135    89.0                        5388.706947              13.934025
#
#       Average Number of Physically Unhealthy Days  \
# 0                                        4.743889
# 1                                        4.224519
# 2                                        5.430279
# 3                                        4.591482
# 4                                        4.860808
# ...                                           ...
# 3131                                     3.402029
# 3132                                     3.031233
# 3133                                     3.628488
# 3134                                     3.613308
# 3135                                     3.463619
#
#       Average Number of Mentally Unhealthy Days  % Low Birthweight  % Smokers  \
# 0                                      4.654031           8.619529  18.081557
# 1                                      4.304056           8.345003  17.489033
# 2                                      5.185594          11.474559  21.999985
# 3                                      4.551699          10.308710  19.114200
# 4                                      4.891455           7.604563  19.208672
# ...                                         ...                ...        ...
# 3131                                   3.623554           9.705248  18.073422
# 3132                                   3.180613           7.736721  14.546369
# 3133                                   3.669805          10.110206  17.212675
# 3134                                   3.682514           7.028754  16.859400
# 3135                                   3.660440           6.589147  16.693134
#
#       Food Environment Index  % Physically Inactive  \
# 0                        7.2                   34.7
# 1                        8.0                   26.5
# 2                        5.6                   23.5
# 3                        7.8                   33.5
# 4                        8.4                   30.3
# ...                      ...                    ...
# 3131                     7.7                   25.0
# 3132                     8.2                   11.6
# 3133                     7.4                   27.2
# 3134                     8.3                   28.2
# 3135                     7.9                   26.9
#
#       % With Access to Exercise Opportunities  ...  % Diagnosed Diabetes  \
# 0                                   69.130124  ...                  11.4
# 1                                   73.713549  ...                   8.2
# 2                                   53.166770  ...                  15.1
# 3                                   16.251364  ...                  12.2
# 4                                   15.634486  ...                  12.2
# ...                                       ...  ...                   ...
# 3131                                89.686344  ...                   8.0
# 3132                                99.718230  ...                   2.2
# 3133                                84.018373  ...                   9.5
# 3134                                83.182937  ...                   8.2
# 3135                                63.027192  ...                   9.2
#
#       % Nonwhite  % households wo car  Number of Hospitals  % disabled  \
# 0      23.121377             0.056569                  1.0        19.3
# 1      13.733800             0.035530                  4.0        14.0
# 2      52.618106             0.092373                  1.0        22.2
# 3      23.345319             0.059283                  1.0        16.7
# 4       4.494752             0.041373                  1.0        14.2
# ...          ...                  ...                  ...         ...
# 3131    6.874901             0.023849                  2.0        12.3
# 3132    9.657834             0.024787                  1.0         7.0
# 3133    6.584502             0.039195                  2.0        17.2
# 3134   10.284168             0.049284                  1.0        14.9
# 3135    7.464789             0.025456                  1.0        14.4
#
#       % Without Health Insurance  % Limited English Proficiency  \
# 0                           10.0                       0.653564
# 1                           13.2                       1.424538
# 2                           13.5                       1.469628
# 3                           10.6                       0.687135
# 4                           14.1                       1.461165
# ...                          ...                            ...
# 3131                        11.5                       2.400605
# 3132                        13.4                       5.033850
# 3133                        11.8                       0.439560
# 3134                        14.8                       1.285798
# 3135                        12.7                       2.122796
#
#       % workers commuting by public transit  \
# 0                                       0.1
# 1                                       0.1
# 2                                       0.3
# 3                                       0.5
# 4                                       0.1
# ...                                     ...
# 3131                                    2.5
# 3132                                    4.1
# 3133                                    3.6
# 3134                                    0.0
# 3135                                    8.3
#
#       % Veterans in Civilian Adult Population  opioid death rate
# 0                                      12.283           8.992644
# 1                                      11.938           6.421370
# 2                                       7.672          20.095655
# 3                                       7.152          22.321429
# 4                                       8.532           8.644537
# ...                                       ...                ...
# 3131                                    8.256          11.614132
# 3132                                    5.283          21.662840
# 3133                                    7.919          24.631755
# 3134                                   12.006          63.411541
# 3135                                   10.849          71.766901
#
# [3135 rows x 83 columns]

# %%
# for correlation 0.5

X_red=X.drop(feat_drop_corr[0][0.5][-1],axis=1)
X_red
# Out:
#       Deaths  Years of Potential Life Lost Rate  \
# 0      791.0                        8128.591190
# 1     2967.0                        7354.122530
# 2      472.0                       10253.573403
# 3      471.0                       11977.539484
# 4     1085.0                       11335.071134
# ...      ...                                ...
# 3131   532.0                        7831.827655
# 3132   109.0                        2730.603992
# 3133   256.0                        7330.683549
# 3134   110.0                        6586.049959
# 3135    89.0                        5388.706947
#
#       % With Access to Exercise Opportunities  \
# 0                                   69.130124
# 1                                   73.713549
# 2                                   53.166770
# 3                                   16.251364
# 4                                   15.634486
# ...                                       ...
# 3131                                89.686344
# 3132                                99.718230
# 3133                                84.018373
# 3134                                83.182937
# 3135                                63.027192
#
#       % Driving Deaths with Alcohol Involvement  Chlamydia Rate  \
# 0                                     26.785714           407.2
# 1                                     30.769231           325.0
# 2                                     40.000000           716.3
# 3                                     27.586207           339.7
# 4                                     19.444444           234.4
# ...                                         ...             ...
# 3131                                  33.962264           227.4
# 3132                                  22.222222           348.2
# 3133                                  20.000000           151.3
# 3134                                  20.000000           223.2
# 3135                                  40.000000           231.0
#
#       Primary Care Physicians Rate  % With Annual Mammogram  \
# 0                         45.04180                     41.0
# 1                         72.89727                     43.0
# 2                         31.65809                     45.0
# 3                         48.52656                     40.0
# 4                         22.40877                     34.0
# ...                            ...                      ...
# 3131                      36.75288                     37.0
# 3132                     116.05416                     42.0
# 3133                      43.91315                     31.0
# 3134                      49.60317                     30.0
# 3135                      43.30879                     31.0
#
#       High School Graduation Rate  Social Association Rate  \
# 0                       90.000000                12.071202
# 1                       86.361577                10.205617
# 2                       81.410256                 7.518797
# 3                       83.763838                 8.381860
# 4                       93.468795                 8.446383
# ...                           ...                      ...
# 3131                    80.500000                10.336748
# 3132                    87.765957                16.333548
# 3133                    84.687500                 2.927543
# 3134                    84.536082                16.121032
# 3135                    90.476190                12.992638
#
#       Violent Crime Rate  ...  % less than 18 years of age  \
# 0             272.282220  ...                    23.674035
# 1             203.660396  ...                    21.607911
# 2             414.277861  ...                    20.867328
# 3              89.349126  ...                    20.477679
# 4             482.690611  ...                    23.153527
# ...                  ...  ...                          ...
# 3131          300.494146  ...                    26.224710
# 3132            0.000000  ...                    18.365755
# 3133           71.006517  ...                    28.789596
# 3134           78.266105  ...                    22.739379
# 3135          157.128680  ...                    20.769341
#
#       % American Indian & Alaska Native   % Asian  \
# 0                              0.480207  1.224798
# 1                              0.772399  1.150343
# 2                              0.659137  0.454162
# 3                              0.437500  0.236607
# 4                              0.653527  0.319848
# ...                                 ...       ...
# 3131                           1.544680  1.010429
# 3132                           0.914172  1.412417
# 3133                           1.418789  0.472930
# 3134                           1.813570  0.824350
# 3135                           1.765466  1.937706
#
#       % Native Hawaiian/Other Pacific Islander  % Hispanic   % Female  \
# 0                                     0.111509    2.965774  51.448715
# 1                                     0.066966    4.646779  51.538377
# 2                                     0.184880    4.276355  47.216752
# 3                                     0.116071    2.625000  46.781250
# 4                                     0.121024    9.571231  50.726141
# ...                                        ...         ...        ...
# 3131                                  0.157952   16.083250  48.544749
# 3132                                  0.151640   14.878038  48.403449
# 3133                                  0.147791    9.236908  49.332479
# 3134                                  0.101458   14.051997  49.422955
# 3135                                  0.028707    4.076360  47.050380
#
#       internet_ratio  Hypertension Death Rate  % households wo car  \
# 0              0.750                    179.6             0.056569
# 1              0.920                    143.4             0.035530
# 2              0.540                    217.2             0.092373
# 3              0.698                    143.3             0.059283
# 4              0.620                    112.4             0.041373
# ...              ...                      ...                  ...
# 3131           0.780                    246.9             0.023849
# 3132           1.090                     55.3             0.024787
# 3133           0.820                    190.5             0.039195
# 3134           0.760                    235.8             0.049284
# 3135           0.590                    267.7             0.025456
#
#       % Veterans in Civilian Adult Population
# 0                                      12.283
# 1                                      11.938
# 2                                       7.672
# 3                                       7.152
# 4                                       8.532
# ...                                       ...
# 3131                                    8.256
# 3132                                    5.283
# 3133                                    7.919
# 3134                                   12.006
# 3135                                   10.849
#
# [3135 rows x 33 columns]

# %%
X_red_corr=X_red.corr()
X_red_corr
# Out:
#                                              Deaths  \
# Deaths                                     1.000000
# Years of Potential Life Lost Rate         -0.017668
# % With Access to Exercise Opportunities    0.301847
# % Driving Deaths with Alcohol Involvement -0.008521
# Chlamydia Rate                             0.187565
# Primary Care Physicians Rate               0.207718
# % With Annual Mammogram                    0.029703
# High School Graduation Rate               -0.004897
# Social Association Rate                   -0.144480
# Violent Crime Rate                         0.294999
# Average Daily PM2.5                        0.191380
# % Severe Housing Problems                  0.311317
# % Long Commute - Drives Alone              0.121647
# Life Expectancy                            0.086445
# Child Mortality Rate                       0.140898
# HIV Prevalence Rate                        0.349851
# Drug Overdose Mortality Rate               0.238940
# % Children Uninsured                      -0.136452
# % Disconnected Youth                       0.161343
# Average Reading Performance               -0.079822
# Black/White Segregation Index              0.281278
# Suicide Rate (Age-Adjusted)                0.013287
# Juvenile Arrest Rate                       0.018345
# % less than 18 years of age                0.024197
# % American Indian & Alaska Native         -0.047421
# % Asian                                    0.406470
# % Native Hawaiian/Other Pacific Islander   0.081035
# % Hispanic                                 0.174954
# % Female                                   0.148425
# internet_ratio                             0.195805
# Hypertension Death Rate                   -0.030687
# % households wo car                        0.087604
# % Veterans in Civilian Adult Population   -0.141652
#
#                                            Years of Potential Life Lost Rate  \
# Deaths                                                             -0.017668
# Years of Potential Life Lost Rate                                   1.000000
# % With Access to Exercise Opportunities                            -0.137928
# % Driving Deaths with Alcohol Involvement                           0.009298
# Chlamydia Rate                                                      0.402579
# Primary Care Physicians Rate                                       -0.107445
# % With Annual Mammogram                                            -0.232284
# High School Graduation Rate                                         0.085467
# Social Association Rate                                            -0.120049
# Violent Crime Rate                                                  0.276980
# Average Daily PM2.5                                                 0.345953
# % Severe Housing Problems                                           0.214398
# % Long Commute - Drives Alone                                       0.146348
# Life Expectancy                                                     0.115342
# Child Mortality Rate                                                0.438111
# HIV Prevalence Rate                                                 0.208380
# Drug Overdose Mortality Rate                                        0.285883
# % Children Uninsured                                               -0.230576
# % Disconnected Youth                                                0.269181
# Average Reading Performance                                         0.105443
# Black/White Segregation Index                                       0.204037
# Suicide Rate (Age-Adjusted)                                         0.402820
# Juvenile Arrest Rate                                                0.075788
# % less than 18 years of age                                         0.132995
# % American Indian & Alaska Native                                   0.245950
# % Asian                                                            -0.176618
# % Native Hawaiian/Other Pacific Islander                           -0.036088
# % Hispanic                                                         -0.124648
# % Female                                                            0.152937
# internet_ratio                                                     -0.300088
# Hypertension Death Rate                                             0.307485
# % households wo car                                                 0.099481
# % Veterans in Civilian Adult Population                            -0.040213
#
#                                            % With Access to Exercise Opportunities  \
# Deaths                                                                    0.301847
# Years of Potential Life Lost Rate                                        -0.137928
# % With Access to Exercise Opportunities                                   1.000000
# % Driving Deaths with Alcohol Involvement                                 0.033225
# Chlamydia Rate                                                            0.076998
# Primary Care Physicians Rate                                              0.437226
# % With Annual Mammogram                                                   0.191111
# High School Graduation Rate                                               0.054451
# Social Association Rate                                                   0.004998
# Violent Crime Rate                                                        0.158837
# Average Daily PM2.5                                                      -0.047243
# % Severe Housing Problems                                                 0.246965
# % Long Commute - Drives Alone                                            -0.205049
# Life Expectancy                                                           0.246341
# Child Mortality Rate                                                      0.083793
# HIV Prevalence Rate                                                       0.077554
# Drug Overdose Mortality Rate                                              0.245585
# % Children Uninsured                                                     -0.269748
# % Disconnected Youth                                                      0.096381
# Average Reading Performance                                              -0.027720
# Black/White Segregation Index                                             0.292437
# Suicide Rate (Age-Adjusted)                                               0.153368
# Juvenile Arrest Rate                                                      0.231253
# % less than 18 years of age                                              -0.056970
# % American Indian & Alaska Native                                        -0.045669
# % Asian                                                                   0.361690
# % Native Hawaiian/Other Pacific Islander                                  0.100095
# % Hispanic                                                                0.107530
# % Female                                                                  0.115730
# internet_ratio                                                            0.453612
# Hypertension Death Rate                                                  -0.196287
# % households wo car                                                       0.059509
# % Veterans in Civilian Adult Population                                   0.004343
#
#                                            % Driving Deaths with Alcohol Involvement  \
# Deaths                                                                     -0.008521
# Years of Potential Life Lost Rate                                           0.009298
# % With Access to Exercise Opportunities                                     0.033225
# % Driving Deaths with Alcohol Involvement                                   1.000000
# Chlamydia Rate                                                              0.006221
# Primary Care Physicians Rate                                               -0.007610
# % With Annual Mammogram                                                     0.063390
# High School Graduation Rate                                                -0.053566
# Social Association Rate                                                    -0.014958
# Violent Crime Rate                                                         -0.000802
# Average Daily PM2.5                                                        -0.118548
# % Severe Housing Problems                                                   0.003563
# % Long Commute - Drives Alone                                              -0.011059
# Life Expectancy                                                             0.058838
# Child Mortality Rate                                                        0.000349
# HIV Prevalence Rate                                                        -0.058350
# Drug Overdose Mortality Rate                                                0.000956
# % Children Uninsured                                                       -0.045784
# % Disconnected Youth                                                        0.015209
# Average Reading Performance                                                -0.013919
# Black/White Segregation Index                                              -0.030483
# Suicide Rate (Age-Adjusted)                                                 0.034829
# Juvenile Arrest Rate                                                        0.005434
# % less than 18 years of age                                                -0.049747
# % American Indian & Alaska Native                                           0.117535
# % Asian                                                                    -0.009090
# % Native Hawaiian/Other Pacific Islander                                    0.029305
# % Hispanic                                                                 -0.078919
# % Female                                                                   -0.030508
# internet_ratio                                                              0.072827
# Hypertension Death Rate                                                    -0.036144
# % households wo car                                                        -0.009330
# % Veterans in Civilian Adult Population                                     0.109209
#
#                                            Chlamydia Rate  \
# Deaths                                           0.187565
# Years of Potential Life Lost Rate                0.402579
# % With Access to Exercise Opportunities          0.076998
# % Driving Deaths with Alcohol Involvement        0.006221
# Chlamydia Rate                                   1.000000
# Primary Care Physicians Rate                     0.076632
# % With Annual Mammogram                         -0.100677
# High School Graduation Rate                     -0.062451
# Social Association Rate                         -0.101996
# Violent Crime Rate                               0.424520
# Average Daily PM2.5                              0.151002
# % Severe Housing Problems                        0.475370
# % Long Commute - Drives Alone                   -0.052379
# Life Expectancy                                  0.061942
# Child Mortality Rate                             0.427459
# HIV Prevalence Rate                              0.425247
# Drug Overdose Mortality Rate                     0.062888
# % Children Uninsured                            -0.119008
# % Disconnected Youth                             0.280511
# Average Reading Performance                     -0.008047
# Black/White Segregation Index                    0.217633
# Suicide Rate (Age-Adjusted)                      0.120544
# Juvenile Arrest Rate                             0.132579
# % less than 18 years of age                      0.218170
# % American Indian & Alaska Native                0.329036
# % Asian                                          0.116058
# % Native Hawaiian/Other Pacific Islander         0.040527
# % Hispanic                                       0.079894
# % Female                                         0.175541
# internet_ratio                                  -0.100748
# Hypertension Death Rate                          0.224357
# % households wo car                              0.189380
# % Veterans in Civilian Adult Population         -0.154365
#
#                                            Primary Care Physicians Rate  \
# Deaths                                                         0.207718
# Years of Potential Life Lost Rate                             -0.107445
# % With Access to Exercise Opportunities                        0.437226
# % Driving Deaths with Alcohol Involvement                     -0.007610
# Chlamydia Rate                                                 0.076632
# Primary Care Physicians Rate                                   1.000000
# % With Annual Mammogram                                        0.223364
# High School Graduation Rate                                    0.061726
# Social Association Rate                                        0.101867
# Violent Crime Rate                                             0.118736
# Average Daily PM2.5                                           -0.087314
# % Severe Housing Problems                                      0.180715
# % Long Commute - Drives Alone                                 -0.295566
# Life Expectancy                                                0.190999
# Child Mortality Rate                                           0.080313
# HIV Prevalence Rate                                            0.073395
# Drug Overdose Mortality Rate                                   0.172990
# % Children Uninsured                                          -0.206488
# % Disconnected Youth                                           0.035752
# Average Reading Performance                                   -0.038761
# Black/White Segregation Index                                  0.207564
# Suicide Rate (Age-Adjusted)                                    0.069578
# Juvenile Arrest Rate                                           0.133547
# % less than 18 years of age                                   -0.080973
# % American Indian & Alaska Native                             -0.014183
# % Asian                                                        0.299638
# % Native Hawaiian/Other Pacific Islander                       0.060195
# % Hispanic                                                    -0.041622
# % Female                                                       0.192481
# internet_ratio                                                 0.299834
# Hypertension Death Rate                                       -0.158610
# % households wo car                                            0.030918
# % Veterans in Civilian Adult Population                       -0.032667
#
#                                            % With Annual Mammogram  \
# Deaths                                                    0.029703
# Years of Potential Life Lost Rate                        -0.232284
# % With Access to Exercise Opportunities                   0.191111
# % Driving Deaths with Alcohol Involvement                 0.063390
# Chlamydia Rate                                           -0.100677
# Primary Care Physicians Rate                              0.223364
# % With Annual Mammogram                                   1.000000
# High School Graduation Rate                               0.023965
# Social Association Rate                                   0.269884
# Violent Crime Rate                                       -0.073083
# Average Daily PM2.5                                       0.116738
# % Severe Housing Problems                                -0.208442
# % Long Commute - Drives Alone                            -0.036963
# Life Expectancy                                           0.146829
# Child Mortality Rate                                     -0.027848
# HIV Prevalence Rate                                      -0.045603
# Drug Overdose Mortality Rate                              0.051317
# % Children Uninsured                                     -0.326884
# % Disconnected Youth                                     -0.069180
# Average Reading Performance                               0.132607
# Black/White Segregation Index                             0.121335
# Suicide Rate (Age-Adjusted)                              -0.095125
# Juvenile Arrest Rate                                      0.077716
# % less than 18 years of age                              -0.191450
# % American Indian & Alaska Native                        -0.258528
# % Asian                                                  -0.010796
# % Native Hawaiian/Other Pacific Islander                 -0.065244
# % Hispanic                                               -0.331291
# % Female                                                  0.172321
# internet_ratio                                            0.213300
# Hypertension Death Rate                                  -0.195727
# % households wo car                                      -0.153047
# % Veterans in Civilian Adult Population                   0.071158
#
#                                            High School Graduation Rate  \
# Deaths                                                       -0.004897
# Years of Potential Life Lost Rate                             0.085467
# % With Access to Exercise Opportunities                       0.054451
# % Driving Deaths with Alcohol Involvement                    -0.053566
# Chlamydia Rate                                               -0.062451
# Primary Care Physicians Rate                                  0.061726
# % With Annual Mammogram                                       0.023965
# High School Graduation Rate                                   1.000000
# Social Association Rate                                      -0.000787
# Violent Crime Rate                                           -0.002081
# Average Daily PM2.5                                           0.262069
# % Severe Housing Problems                                    -0.043293
# % Long Commute - Drives Alone                                 0.083036
# Life Expectancy                                               0.241771
# Child Mortality Rate                                          0.046180
# HIV Prevalence Rate                                          -0.038673
# Drug Overdose Mortality Rate                                  0.082204
# % Children Uninsured                                         -0.162605
# % Disconnected Youth                                         -0.000600
# Average Reading Performance                                   0.171898
# Black/White Segregation Index                                 0.100844
# Suicide Rate (Age-Adjusted)                                   0.052287
# Juvenile Arrest Rate                                          0.043113
# % less than 18 years of age                                  -0.014650
# % American Indian & Alaska Native                            -0.192409
# % Asian                                                      -0.010532
# % Native Hawaiian/Other Pacific Islander                     -0.018249
# % Hispanic                                                   -0.005573
# % Female                                                      0.052380
# internet_ratio                                               -0.024252
# Hypertension Death Rate                                      -0.028642
# % households wo car                                          -0.087014
# % Veterans in Civilian Adult Population                       0.021359
#
#                                            Social Association Rate  \
# Deaths                                                   -0.144480
# Years of Potential Life Lost Rate                        -0.120049
# % With Access to Exercise Opportunities                   0.004998
# % Driving Deaths with Alcohol Involvement                -0.014958
# Chlamydia Rate                                           -0.101996
# Primary Care Physicians Rate                              0.101867
# % With Annual Mammogram                                   0.269884
# High School Graduation Rate                              -0.000787
# Social Association Rate                                   1.000000
# Violent Crime Rate                                       -0.095534
# Average Daily PM2.5                                      -0.025886
# % Severe Housing Problems                                -0.318421
# % Long Commute - Drives Alone                            -0.270848
# Life Expectancy                                           0.088170
# Child Mortality Rate                                     -0.113149
# HIV Prevalence Rate                                      -0.151081
# Drug Overdose Mortality Rate                             -0.133749
# % Children Uninsured                                      0.026199
# % Disconnected Youth                                     -0.140254
# Average Reading Performance                               0.162415
# Black/White Segregation Index                            -0.088307
# Suicide Rate (Age-Adjusted)                              -0.143464
# Juvenile Arrest Rate                                      0.095543
# % less than 18 years of age                              -0.056835
# % American Indian & Alaska Native                        -0.119492
# % Asian                                                  -0.141100
# % Native Hawaiian/Other Pacific Islander                 -0.083181
# % Hispanic                                               -0.175613
# % Female                                                  0.109522
# internet_ratio                                           -0.056277
# Hypertension Death Rate                                   0.006876
# % households wo car                                      -0.056907
# % Veterans in Civilian Adult Population                   0.040183
#
#                                            Violent Crime Rate  ...  \
# Deaths                                               0.294999  ...
# Years of Potential Life Lost Rate                    0.276980  ...
# % With Access to Exercise Opportunities              0.158837  ...
# % Driving Deaths with Alcohol Involvement           -0.000802  ...
# Chlamydia Rate                                       0.424520  ...
# Primary Care Physicians Rate                         0.118736  ...
# % With Annual Mammogram                             -0.073083  ...
# High School Graduation Rate                         -0.002081  ...
# Social Association Rate                             -0.095534  ...
# Violent Crime Rate                                   1.000000  ...
# Average Daily PM2.5                                  0.185351  ...
# % Severe Housing Problems                            0.305204  ...
# % Long Commute - Drives Alone                       -0.045971  ...
# Life Expectancy                                      0.043805  ...
# Child Mortality Rate                                 0.320124  ...
# HIV Prevalence Rate                                  0.466167  ...
# Drug Overdose Mortality Rate                         0.197642  ...
# % Children Uninsured                                -0.147764  ...
# % Disconnected Youth                                 0.254836  ...
# Average Reading Performance                         -0.049567  ...
# Black/White Segregation Index                        0.284074  ...
# Suicide Rate (Age-Adjusted)                          0.121784  ...
# Juvenile Arrest Rate                                 0.102839  ...
# % less than 18 years of age                          0.040469  ...
# % American Indian & Alaska Native                   -0.026967  ...
# % Asian                                              0.131400  ...
# % Native Hawaiian/Other Pacific Islander             0.059611  ...
# % Hispanic                                           0.149293  ...
# % Female                                             0.142806  ...
# internet_ratio                                      -0.004192  ...
# Hypertension Death Rate                              0.134726  ...
# % households wo car                                  0.118501  ...
# % Veterans in Civilian Adult Population             -0.051781  ...
#
#                                            % less than 18 years of age  \
# Deaths                                                        0.024197
# Years of Potential Life Lost Rate                             0.132995
# % With Access to Exercise Opportunities                      -0.056970
# % Driving Deaths with Alcohol Involvement                    -0.049747
# Chlamydia Rate                                                0.218170
# Primary Care Physicians Rate                                 -0.080973
# % With Annual Mammogram                                      -0.191450
# High School Graduation Rate                                  -0.014650
# Social Association Rate                                      -0.056835
# Violent Crime Rate                                            0.040469
# Average Daily PM2.5                                           0.027332
# % Severe Housing Problems                                     0.034166
# % Long Commute - Drives Alone                                -0.124112
# Life Expectancy                                               0.024546
# Child Mortality Rate                                          0.163116
# HIV Prevalence Rate                                          -0.077941
# Drug Overdose Mortality Rate                                 -0.099994
# % Children Uninsured                                          0.193156
# % Disconnected Youth                                          0.153384
# Average Reading Performance                                   0.093426
# Black/White Segregation Index                                 0.006497
# Suicide Rate (Age-Adjusted)                                   0.020832
# Juvenile Arrest Rate                                          0.009874
# % less than 18 years of age                                   1.000000
# % American Indian & Alaska Native                             0.305415
# % Asian                                                      -0.014933
# % Native Hawaiian/Other Pacific Islander                      0.048017
# % Hispanic                                                    0.304511
# % Female                                                      0.181160
# internet_ratio                                               -0.139708
# Hypertension Death Rate                                       0.170889
# % households wo car                                           0.016080
# % Veterans in Civilian Adult Population                      -0.256033
#
#                                            % American Indian & Alaska Native  \
# Deaths                                                             -0.047421
# Years of Potential Life Lost Rate                                   0.245950
# % With Access to Exercise Opportunities                            -0.045669
# % Driving Deaths with Alcohol Involvement                           0.117535
# Chlamydia Rate                                                      0.329036
# Primary Care Physicians Rate                                       -0.014183
# % With Annual Mammogram                                            -0.258528
# High School Graduation Rate                                        -0.192409
# Social Association Rate                                            -0.119492
# Violent Crime Rate                                                 -0.026967
# Average Daily PM2.5                                                -0.316649
# % Severe Housing Problems                                           0.284937
# % Long Commute - Drives Alone                                      -0.169291
# Life Expectancy                                                    -0.067288
# Child Mortality Rate                                                0.096375
# HIV Prevalence Rate                                                -0.089969
# Drug Overdose Mortality Rate                                       -0.078467
# % Children Uninsured                                                0.197654
# % Disconnected Youth                                                0.182684
# Average Reading Performance                                        -0.126241
# Black/White Segregation Index                                      -0.110207
# Suicide Rate (Age-Adjusted)                                         0.206972
# Juvenile Arrest Rate                                                0.050846
# % less than 18 years of age                                         0.305415
# % American Indian & Alaska Native                                   1.000000
# % Asian                                                            -0.009832
# % Native Hawaiian/Other Pacific Islander                            0.019396
# % Hispanic                                                          0.005914
# % Female                                                           -0.071780
# internet_ratio                                                     -0.047732
# Hypertension Death Rate                                             0.073490
# % households wo car                                                 0.231143
# % Veterans in Civilian Adult Population                            -0.025013
#
#                                             % Asian  \
# Deaths                                     0.406470
# Years of Potential Life Lost Rate         -0.176618
# % With Access to Exercise Opportunities    0.361690
# % Driving Deaths with Alcohol Involvement -0.009090
# Chlamydia Rate                             0.116058
# Primary Care Physicians Rate               0.299638
# % With Annual Mammogram                   -0.010796
# High School Graduation Rate               -0.010532
# Social Association Rate                   -0.141100
# Violent Crime Rate                         0.131400
# Average Daily PM2.5                       -0.037536
# % Severe Housing Problems                  0.326113
# % Long Commute - Drives Alone              0.025471
# Life Expectancy                            0.133163
# Child Mortality Rate                       0.038311
# HIV Prevalence Rate                        0.204904
# Drug Overdose Mortality Rate               0.081875
# % Children Uninsured                      -0.118934
# % Disconnected Youth                       0.061078
# Average Reading Performance               -0.127588
# Black/White Segregation Index              0.190633
# Suicide Rate (Age-Adjusted)               -0.036167
# Juvenile Arrest Rate                       0.008657
# % less than 18 years of age               -0.014933
# % American Indian & Alaska Native         -0.009832
# % Asian                                    1.000000
# % Native Hawaiian/Other Pacific Islander   0.452393
# % Hispanic                                 0.162505
# % Female                                   0.002069
# internet_ratio                             0.269198
# Hypertension Death Rate                   -0.122845
# % households wo car                        0.091257
# % Veterans in Civilian Adult Population   -0.166509
#
#                                            % Native Hawaiian/Other Pacific Islander  \
# Deaths                                                                     0.081035
# Years of Potential Life Lost Rate                                         -0.036088
# % With Access to Exercise Opportunities                                    0.100095
# % Driving Deaths with Alcohol Involvement                                  0.029305
# Chlamydia Rate                                                             0.040527
# Primary Care Physicians Rate                                               0.060195
# % With Annual Mammogram                                                   -0.065244
# High School Graduation Rate                                               -0.018249
# Social Association Rate                                                   -0.083181
# Violent Crime Rate                                                         0.059611
# Average Daily PM2.5                                                       -0.182662
# % Severe Housing Problems                                                  0.186929
# % Long Commute - Drives Alone                                             -0.039903
# Life Expectancy                                                            0.047358
# Child Mortality Rate                                                       0.041111
# HIV Prevalence Rate                                                        0.024918
# Drug Overdose Mortality Rate                                              -0.002782
# % Children Uninsured                                                      -0.024950
# % Disconnected Youth                                                       0.067154
# Average Reading Performance                                               -0.046057
# Black/White Segregation Index                                              0.067243
# Suicide Rate (Age-Adjusted)                                                0.041160
# Juvenile Arrest Rate                                                       0.045502
# % less than 18 years of age                                                0.048017
# % American Indian & Alaska Native                                          0.019396
# % Asian                                                                    0.452393
# % Native Hawaiian/Other Pacific Islander                                   1.000000
# % Hispanic                                                                 0.089180
# % Female                                                                  -0.033926
# internet_ratio                                                             0.076684
# Hypertension Death Rate                                                   -0.017256
# % households wo car                                                        0.023822
# % Veterans in Civilian Adult Population                                    0.039928
#
#                                            % Hispanic  % Female  \
# Deaths                                       0.174954  0.148425
# Years of Potential Life Lost Rate           -0.124648  0.152937
# % With Access to Exercise Opportunities      0.107530  0.115730
# % Driving Deaths with Alcohol Involvement   -0.078919 -0.030508
# Chlamydia Rate                               0.079894  0.175541
# Primary Care Physicians Rate                -0.041622  0.192481
# % With Annual Mammogram                     -0.331291  0.172321
# High School Graduation Rate                 -0.005573  0.052380
# Social Association Rate                     -0.175613  0.109522
# Violent Crime Rate                           0.149293  0.142806
# Average Daily PM2.5                         -0.130371  0.258324
# % Severe Housing Problems                    0.280768  0.077247
# % Long Commute - Drives Alone               -0.124726  0.078700
# Life Expectancy                              0.026628  0.028859
# Child Mortality Rate                        -0.055269  0.201838
# HIV Prevalence Rate                          0.103891 -0.014062
# Drug Overdose Mortality Rate                -0.099579  0.203282
# % Children Uninsured                         0.348900 -0.189637
# % Disconnected Youth                         0.064153  0.017711
# Average Reading Performance                 -0.140957  0.057051
# Black/White Segregation Index                0.036175  0.206045
# Suicide Rate (Age-Adjusted)                 -0.064834  0.067189
# Juvenile Arrest Rate                         0.035631  0.041365
# % less than 18 years of age                  0.304511  0.181160
# % American Indian & Alaska Native            0.005914 -0.071780
# % Asian                                      0.162505  0.002069
# % Native Hawaiian/Other Pacific Islander     0.089180 -0.033926
# % Hispanic                                   1.000000 -0.156405
# % Female                                    -0.156405  1.000000
# internet_ratio                               0.035838  0.002615
# Hypertension Death Rate                      0.070472  0.015517
# % households wo car                         -0.011966  0.012091
# % Veterans in Civilian Adult Population     -0.207391 -0.048434
#
#                                            internet_ratio  \
# Deaths                                           0.195805
# Years of Potential Life Lost Rate               -0.300088
# % With Access to Exercise Opportunities          0.453612
# % Driving Deaths with Alcohol Involvement        0.072827
# Chlamydia Rate                                  -0.100748
# Primary Care Physicians Rate                     0.299834
# % With Annual Mammogram                          0.213300
# High School Graduation Rate                     -0.024252
# Social Association Rate                         -0.056277
# Violent Crime Rate                              -0.004192
# Average Daily PM2.5                             -0.150684
# % Severe Housing Problems                        0.107151
# % Long Commute - Drives Alone                   -0.087436
# Life Expectancy                                  0.068364
# Child Mortality Rate                            -0.053188
# HIV Prevalence Rate                             -0.024828
# Drug Overdose Mortality Rate                     0.162529
# % Children Uninsured                            -0.102746
# % Disconnected Youth                            -0.011580
# Average Reading Performance                     -0.084794
# Black/White Segregation Index                    0.152001
# Suicide Rate (Age-Adjusted)                      0.058687
# Juvenile Arrest Rate                             0.037539
# % less than 18 years of age                     -0.139708
# % American Indian & Alaska Native               -0.047732
# % Asian                                          0.269198
# % Native Hawaiian/Other Pacific Islander         0.076684
# % Hispanic                                       0.035838
# % Female                                         0.002615
# internet_ratio                                   1.000000
# Hypertension Death Rate                         -0.255839
# % households wo car                             -0.058892
# % Veterans in Civilian Adult Population          0.099662
#
#                                            Hypertension Death Rate  \
# Deaths                                                   -0.030687
# Years of Potential Life Lost Rate                         0.307485
# % With Access to Exercise Opportunities                  -0.196287
# % Driving Deaths with Alcohol Involvement                -0.036144
# Chlamydia Rate                                            0.224357
# Primary Care Physicians Rate                             -0.158610
# % With Annual Mammogram                                  -0.195727
# High School Graduation Rate                              -0.028642
# Social Association Rate                                   0.006876
# Violent Crime Rate                                        0.134726
# Average Daily PM2.5                                       0.169406
# % Severe Housing Problems                                 0.033722
# % Long Commute - Drives Alone                             0.007649
# Life Expectancy                                          -0.065922
# Child Mortality Rate                                      0.164862
# HIV Prevalence Rate                                       0.148885
# Drug Overdose Mortality Rate                              0.015103
# % Children Uninsured                                      0.103903
# % Disconnected Youth                                      0.126479
# Average Reading Performance                               0.040484
# Black/White Segregation Index                             0.056822
# Suicide Rate (Age-Adjusted)                              -0.015412
# Juvenile Arrest Rate                                     -0.018143
# % less than 18 years of age                               0.170889
# % American Indian & Alaska Native                         0.073490
# % Asian                                                  -0.122845
# % Native Hawaiian/Other Pacific Islander                 -0.017256
# % Hispanic                                                0.070472
# % Female                                                  0.015517
# internet_ratio                                           -0.255839
# Hypertension Death Rate                                   1.000000
# % households wo car                                       0.044592
# % Veterans in Civilian Adult Population                  -0.080322
#
#                                            % households wo car  \
# Deaths                                                0.087604
# Years of Potential Life Lost Rate                     0.099481
# % With Access to Exercise Opportunities               0.059509
# % Driving Deaths with Alcohol Involvement            -0.009330
# Chlamydia Rate                                        0.189380
# Primary Care Physicians Rate                          0.030918
# % With Annual Mammogram                              -0.153047
# High School Graduation Rate                          -0.087014
# Social Association Rate                              -0.056907
# Violent Crime Rate                                    0.118501
# Average Daily PM2.5                                  -0.048061
# % Severe Housing Problems                             0.291663
# % Long Commute - Drives Alone                        -0.071051
# Life Expectancy                                      -0.075313
# Child Mortality Rate                                  0.100374
# HIV Prevalence Rate                                   0.181310
# Drug Overdose Mortality Rate                          0.049034
# % Children Uninsured                                 -0.019905
# % Disconnected Youth                                  0.086255
# Average Reading Performance                          -0.085192
# Black/White Segregation Index                         0.048308
# Suicide Rate (Age-Adjusted)                          -0.015646
# Juvenile Arrest Rate                                  0.021623
# % less than 18 years of age                           0.016080
# % American Indian & Alaska Native                     0.231143
# % Asian                                               0.091257
# % Native Hawaiian/Other Pacific Islander              0.023822
# % Hispanic                                           -0.011966
# % Female                                              0.012091
# internet_ratio                                       -0.058892
# Hypertension Death Rate                               0.044592
# % households wo car                                   1.000000
# % Veterans in Civilian Adult Population              -0.122133
#
#                                            % Veterans in Civilian Adult Population
# Deaths                                                                   -0.141652
# Years of Potential Life Lost Rate                                        -0.040213
# % With Access to Exercise Opportunities                                   0.004343
# % Driving Deaths with Alcohol Involvement                                 0.109209
# Chlamydia Rate                                                           -0.154365
# Primary Care Physicians Rate                                             -0.032667
# % With Annual Mammogram                                                   0.071158
# High School Graduation Rate                                               0.021359
# Social Association Rate                                                   0.040183
# Violent Crime Rate                                                       -0.051781
# Average Daily PM2.5                                                      -0.136436
# % Severe Housing Problems                                                -0.170782
# % Long Commute - Drives Alone                                             0.032658
# Life Expectancy                                                           0.022354
# Child Mortality Rate                                                     -0.086934
# HIV Prevalence Rate                                                      -0.152784
# Drug Overdose Mortality Rate                                              0.037435
# % Children Uninsured                                                     -0.019380
# % Disconnected Youth                                                     -0.056095
# Average Reading Performance                                               0.019841
# Black/White Segregation Index                                            -0.115675
# Suicide Rate (Age-Adjusted)                                               0.197852
# Juvenile Arrest Rate                                                      0.098474
# % less than 18 years of age                                              -0.256033
# % American Indian & Alaska Native                                        -0.025013
# % Asian                                                                  -0.166509
# % Native Hawaiian/Other Pacific Islander                                  0.039928
# % Hispanic                                                               -0.207391
# % Female                                                                 -0.048434
# internet_ratio                                                            0.099662
# Hypertension Death Rate                                                  -0.080322
# % households wo car                                                      -0.122133
# % Veterans in Civilian Adult Population                                   1.000000
#
# [33 rows x 33 columns]

# %%
import seaborn as sn
import matplotlib.pyplot as plt
plt.figure(figsize=[30,30])
sn.heatmap(X_red_corr, annot=True)
# plt.savefig('heatmap.png')
plt.show()

# %% [markdown]
# # Kmeans

# %%
model=  KMeans(
               n_clusters=6,
               init="k-means++",
               n_init=50,
               max_iter=500,
               random_state=42,
           )
model.fit(X_red)
label=pd.DataFrame(model.labels_)
file['class']=label
file.dropna(inplace=True)
file['class'].value_counts()
file.to_csv('../data/Clustering labelled data1/6_cluster.csv')

# %%
X_red['class'].value_counts()
# Out:
# 3.0    1639
# 0.0    1138
# 1.0     295
# 2.0      51
# Name: class, dtype: int64

# %%
(model.cluster_centers_)
# Out:
# array([[6.43810193e+02, 1.10141588e+04, 5.32658170e+01, 2.72734049e+01,
#         4.80032250e+02, 4.26930076e+01, 3.72293497e+01, 8.63322514e+01,
#         1.11983303e+01, 2.86247454e+02, 9.51326889e+00, 1.44071993e+01,
#         3.34335677e+01, 7.45563116e+01, 5.10945135e+01, 1.70492707e+02,
#         1.47674030e+01, 6.15500711e+00, 5.12585639e+00, 2.50624184e+00,
#         3.05975464e+01, 1.62124706e+01, 1.68447739e+01, 2.22766049e+01,
#         3.74886699e+00, 7.49459615e-01, 9.43917432e-02, 7.39757353e+00,
#         5.01314390e+01, 6.12616872e-01, 3.02310193e+02, 7.50836075e-02,
#         8.74172144e+00, 2.42442882e+00],
#        [1.33762712e+01, 1.00208679e+02, 4.99822809e+01, 2.76039338e+01,
#         1.58740000e+02, 3.92500930e+01, 3.95966102e+01, 7.52951072e+01,
#         1.35195038e+01, 1.09323155e+02, 6.32711864e+00, 1.11293528e+01,
#         2.58969492e+01, 6.23461111e+01, 4.53941730e-01, 2.47572881e+01,
#         1.06281859e-01, 1.08343517e+01, 4.63613466e-02, 1.85397320e+00,
#         1.66609941e+00, 1.40294815e+00, 8.75443911e+00, 2.09772810e+01,
#         2.10886068e+00, 1.07359397e+00, 8.43339371e-02, 1.09191841e+01,
#         4.89384207e+01, 7.25898305e-01, 2.20150169e+02, 6.21900943e-02,
#         9.21942712e+00, 2.91186441e+00],
#        [1.94510784e+04, 7.06447000e+03, 9.48782036e+01, 2.49323009e+01,
#         6.69641176e+02, 8.78074359e+01, 3.96666667e+01, 8.36307155e+01,
#         7.69996483e+00, 5.57357465e+02, 1.04450980e+01, 2.10530338e+01,
#         4.05647059e+01, 7.94301553e+01, 5.21135964e+01, 5.81450980e+02,
#         2.55994345e+01, 4.75149998e+00, 6.87958535e+00, 1.98097801e+00,
#         5.69839914e+01, 1.15162232e+01, 1.73565540e+01, 2.21739886e+01,
#         9.74135696e-01, 8.29063794e+00, 2.21280613e-01, 2.19404186e+01,
#         5.13259219e+01, 8.27254902e-01, 2.51749020e+02, 1.30916488e-01,
#         6.26954902e+00, 3.41176471e+00],
#        [1.26363354e+03, 6.96013068e+03, 7.06053598e+01, 2.86636209e+01,
#         3.47446829e+02, 5.97141567e+01, 4.29664634e+01, 8.81725132e+01,
#         1.18373584e+01, 2.16161903e+02, 8.99274390e+00, 1.37150059e+01,
#         3.09007317e+01, 7.89245043e+01, 3.44286112e+01, 1.14820976e+02,
#         1.26551003e+01, 5.53280741e+00, 3.86335131e+00, 2.48660963e+00,
#         3.35765525e+01, 1.46146515e+01, 2.02864129e+01, 2.21180170e+01,
#         1.31976490e+00, 2.02329569e+00, 1.52266260e-01, 1.05464158e+01,
#         4.98541341e+01, 7.51809756e-01, 2.29394512e+02, 5.65423953e-02,
#         9.06742256e+00, 3.16280488e+00]])

# %%
label=pd.DataFrame(model.labels_)

# %%
label
# Out:
#       0
# 0     3
# 1     3
# 2     0
# 3     0
# 4     0
# ...  ..
# 3119  3
# 3120  0
# 3121  3
# 3122  3
# 3123  3
#
# [3124 rows x 1 columns]

# %%
X_red.shape
# Out:
# (3123, 34)

# %% [markdown]
# ## Using predicted labels as class column for supervised feature importance score and cluster analysis

# %%
X_red['class']=label

# %%
X_red.dropna(inplace=True)

# %%
X_red['class'].unique()
# Out:
# array([3, 0, 2, 1], dtype=int32)

# %%
X1=X_red.drop(['class'],axis=1)

# %%
y1=X_red['class']

# %%
y1.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### To install required package if missing

# %%
# !pip install xgboost

# %%
#class distribution
y1.hist(grid=False)

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X1, y1)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='multi:softprob', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
print(model.feature_importances_)
# Out:
# [0.04887098 0.30090636 0.01661985 0.01622478 0.02002984 0.01458088
#  0.02344222 0.01863964 0.01959388 0.01753457 0.02611624 0.01531499
#  0.01404547 0.03340236 0.01876036 0.02248736 0.0335135  0.04000726
#  0.02264836 0.01865782 0.01651855 0.01876344 0.0267536  0.01902265
#  0.01981694 0.01859534 0.01496361 0.03013487 0.01988485 0.01916217
#  0.01930324 0.01858937 0.01709451]

# %%
from xgboost import plot_importance
from matplotlib import pyplot

# No of top important features to show type=integer
top_n_features=12

plot_importance(model,max_num_features=top_n_features)
pyplot.show()

# %%
from sklearn.metrics import classification_report as clf
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import ExtraTreesClassifier
test_model=ExtraTreesClassifier()

# %%
test_model.fit(X_train,y_train)
# Out:
# ExtraTreesClassifier()

# %%
y_pred = test_model.predict(X_test)
print(clf(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75       367
#            1       0.70      0.58      0.63        90
#            2       1.00      0.10      0.17        21
#            3       0.77      0.86      0.81       553
#
#     accuracy                           0.77      1031
#    macro avg       0.81      0.56      0.59      1031
# weighted avg       0.77      0.77      0.76      1031

# %% [markdown]
# # Cluster Distribution as per death column and some others

# %%
X_val=X_red['Deaths']

# %%
plt.scatter(X_val,y1,)

# %% [markdown]
# ## Scatter Plot

# %%
# to supress warnings
import warnings
warnings.simplefilter(action='ignore')

for i in X1.columns:
    plt.figure(frameon=True,)
    plt.scatter(X1[i],y1)
    plt.title(i)
#     plt.savefig(str(i)+".png")

# %% [markdown]
# ## Violet plot

# %%
import seaborn as sns


for i in X_red.columns:
    plt.figure(frameon=True,)
    sns.violinplot(x='class',y=X_red[i],data=X_red)
#     plt.savefig(str(i)+".png")

# %% [markdown]
# ## Box Plot

# %%
for i in X_red.columns:
    try:
        plt.figure(frameon=True,)
        sns.boxplot(x='class',y=X_red[i],data=X_red)
#         plt.savefig(str(i)+".png")
    except:
        pass

# %% [markdown]
# # Elbow method for number of clusters

# %%
wcss = []  #Within-Cluster-Sum-of-Squares

for i in range(2,15):
    kmeans = KMeans(n_clusters=i,init="k-means++",max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X_red)
    wcss.append(kmeans.inertia_)
    print("Cluster", i, "Inertia", kmeans.inertia_)
plt.plot(range(2,15),wcss)
plt.title("The Elbow Curve")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS") #
plt.show()
# Out:
# Cluster 2 Inertia 49543396699.90004
# Cluster 3 Inertia 32830321889.818897
# Cluster 4 Inertia 22523533123.801563
# Cluster 5 Inertia 15105307322.98617
# Cluster 6 Inertia 12040845244.936367
# Cluster 7 Inertia 9054921710.433065
# Cluster 8 Inertia 7739728240.908474
# Cluster 9 Inertia 6720745750.839849
# Cluster 10 Inertia 5759883515.299273
# Cluster 11 Inertia 4911767904.611418
# Cluster 12 Inertia 4411665400.288563
# Cluster 13 Inertia 3963713015.487391
# Cluster 14 Inertia 3609977901.383002

# %%
wcss = []
for i in range(1,12):
    kmeans = KMeans(n_clusters=i,init="k-means++",max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X_red)
    wcss.append(kmeans.inertia_)
    print("Cluster", i, "Inertia", kmeans.inertia_)
plt.plot(range(1,12),wcss)
plt.title("The Elbow Curve")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS") #
plt.show()
# Out:
# Cluster 1 Inertia 70779840054.27634
# Cluster 2 Inertia 49543396699.90004
# Cluster 3 Inertia 32830321889.8189
# Cluster 4 Inertia 22523533123.80156
# Cluster 5 Inertia 15105307322.98617
# Cluster 6 Inertia 12040845244.936365
# Cluster 7 Inertia 9054921710.433067
# Cluster 8 Inertia 7739728240.908473
# Cluster 9 Inertia 6720745750.839849
# Cluster 10 Inertia 5759883515.2992735
# Cluster 11 Inertia 4911767904.611418

# %%
# 4 cluster seems a good choice

kmeans=  KMeans(
               n_clusters=4,
               init="k-means++",
               n_init=50,
               max_iter=500,
               random_state=42,
           )

# %%
kmeans.fit(X)
# Out:
# KMeans(max_iter=500, n_clusters=4, n_init=50, random_state=42)

# %%
y_pred=kmeans.predict(X)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %% [markdown]
# # Silhoutte Score

# %%
X=X_red

# %%
import seaborn as sns
from sklearn.metrics import silhouette_score
n_clu = []
km_ss = []

start=2
end=30
# Create a for loop to find optimal n_clusters
for n_clusters in range(2,10):

    # Create cluster labels
    kmeans = KMeans(n_clusters=n_clusters)
    labels = kmeans.fit_predict(X)

    silhouette_avg = round(silhouette_score(X, labels, random_state=1), 3)

    # Append score to lists
    km_ss.append(silhouette_avg)
    n_clu.append(n_clusters)

    print("No. Clusters: {}, Silhouette Score: {}, Change from Previous Cluster: {}".format(
        n_clusters, silhouette_avg, (km_ss[n_clusters - start] - km_ss[n_clusters - start - 1]).round(3)))

    # Plot graph at the end of loop
    if n_clusters == end - 1:
        plt.figure(figsize=(12,4))

        plt.title('Silhouette Score')
        plt.xlabel("Number of clusters")
        sns.pointplot(x=n_clu, y=km_ss)
        plt.tight_layout()
        plt.show()
# Out:
# No. Clusters: 2, Silhouette Score: 0.437, Change from Previous Cluster: 0.0
# No. Clusters: 3, Silhouette Score: 0.454, Change from Previous Cluster: 0.017
# No. Clusters: 4, Silhouette Score: 0.474, Change from Previous Cluster: 0.02
# No. Clusters: 5, Silhouette Score: 0.497, Change from Previous Cluster: 0.023
# No. Clusters: 6, Silhouette Score: 0.509, Change from Previous Cluster: 0.012
# No. Clusters: 7, Silhouette Score: 0.471, Change from Previous Cluster: -0.038
# No. Clusters: 8, Silhouette Score: 0.429, Change from Previous Cluster: -0.042
# No. Clusters: 9, Silhouette Score: 0.445, Change from Previous Cluster: 0.016
# No. Clusters: 10, Silhouette Score: 0.437, Change from Previous Cluster: -0.008
# No. Clusters: 11, Silhouette Score: 0.422, Change from Previous Cluster: -0.015
# No. Clusters: 12, Silhouette Score: 0.433, Change from Previous Cluster: 0.011
# No. Clusters: 13, Silhouette Score: 0.406, Change from Previous Cluster: -0.027
# No. Clusters: 14, Silhouette Score: 0.415, Change from Previous Cluster: 0.009
# No. Clusters: 15, Silhouette Score: 0.4, Change from Previous Cluster: -0.015
# No. Clusters: 16, Silhouette Score: 0.412, Change from Previous Cluster: 0.012
# No. Clusters: 17, Silhouette Score: 0.416, Change from Previous Cluster: 0.004
# No. Clusters: 18, Silhouette Score: 0.379, Change from Previous Cluster: -0.037
# No. Clusters: 19, Silhouette Score: 0.392, Change from Previous Cluster: 0.013
# No. Clusters: 20, Silhouette Score: 0.386, Change from Previous Cluster: -0.006
# No. Clusters: 21, Silhouette Score: 0.398, Change from Previous Cluster: 0.012
# No. Clusters: 22, Silhouette Score: 0.384, Change from Previous Cluster: -0.014
# No. Clusters: 23, Silhouette Score: 0.377, Change from Previous Cluster: -0.007
# No. Clusters: 24, Silhouette Score: 0.382, Change from Previous Cluster: 0.005
# No. Clusters: 25, Silhouette Score: 0.383, Change from Previous Cluster: 0.001
# No. Clusters: 26, Silhouette Score: 0.361, Change from Previous Cluster: -0.022
# No. Clusters: 27, Silhouette Score: 0.363, Change from Previous Cluster: 0.002
# No. Clusters: 28, Silhouette Score: 0.362, Change from Previous Cluster: -0.001
# No. Clusters: 29, Silhouette Score: 0.343, Change from Previous Cluster: -0.019

# %% [markdown]
# # Davies_bouldin_score
#
# This index signifies the average ‘similarity’ between clusters, where the similarity is a measure that compares the distance between clusters with the size of the clusters themselves.
#
# Zero is the lowest possible score. Values closer to zero indicate a better partition.

# %% [markdown]
# ### 4 or 6 seems good choice

# %%
from sklearn.metrics import davies_bouldin_score
for i in range(2,10):
    kmeans = KMeans(n_clusters=i,init="k-means++",max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X)
    labels = kmeans.labels_
    score=davies_bouldin_score(X, labels)
    print("Cluster", i, "Davis Score", score)

# %% [markdown]
# # Calinski-Harabasz Index
#
# The index is the ratio of the sum of between-clusters dispersion and of inter-cluster dispersion for all clusters (where dispersion is defined as the sum of distances squared).
#
# The score is higher when clusters are dense and well separated.

# %%
from sklearn import metrics
from sklearn.metrics import pairwise_distances
for i in range(2,10):
    kmeans = KMeans(n_clusters=i,init="k-means++",max_iter=300,n_init=10,random_state=0)
    kmeans.fit(X)
    labels = kmeans.labels_
    score=metrics.calinski_harabasz_score(X, labels)
    print("Cluster", i, "Calinski index", score)
